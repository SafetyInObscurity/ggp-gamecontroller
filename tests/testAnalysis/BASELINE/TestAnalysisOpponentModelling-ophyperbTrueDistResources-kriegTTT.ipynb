# %% [markdown]
# # <center>OP Hyper Bias</center>
#
# This file is an interactive notebook to analyze the data obtained from tests.<br>
# The purpose of this notebook is to define a baseline for a model which can be improved upon.
# The game blind_breakthrough will be used since this seems to be the game the original hyperplay model performed the best at.
#
# **Note: It could be a good idea to look into using a stronger cheat agent for a better comparison**
#
# ## Reading in the Data
#
# First the match data must be read in.
# I will be reading in data obtained for a series of games where a hyperplayer with increasing resources competed against a CHEAT player who had access to the true state and was allowed 16 simulations per move.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import statistics
np.random.seed(42)

# Read in the csv files
numNames = ['2x2', '4x4', '8x8', '16x16', '32x32']
data = list()

for idx, name in enumerate(numNames):
    file_name = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ophyperb_resources/' + name + '/testOutput.csv'
    data.append(pd.DataFrame)
    data[idx] = pd.read_csv(file_name, header=0)

# Read in the csv files
numNames = ['2x2', '4x4', '8x8', '16x16', '32x32']
data_ahyper = list()

for idx, name in enumerate(numNames):
    file_name = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ahyperlt_resources/' + name + '/testOutput.csv'
    data_ahyper.append(pd.DataFrame)
    data_ahyper[idx] = pd.read_csv(file_name, header=0)
    
# Print the first 5 rows of the data
for game in data:
    display(game.head())
# Out:
#                                           match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1598975450636          10        300  XPLAYER          6
# 1            2  1598975531542          10        300  XPLAYER          7
# 2            2  1598975606381          10        300  XPLAYER          7
# 3            2  1598975655311          10        300  XPLAYER          4
# 4            2  1598975723938          10        300  XPLAYER          6
#
#     role_1  player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 2  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPERB               0  oplayer    CHEAT             100
#                                           match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1598975542990          10        300  XPLAYER          6
# 1            2  1598975635341          10        300  XPLAYER          5
# 2            2  1598975774734          10        300  XPLAYER          8
# 3            2  1598975875827          10        300  XPLAYER          6
# 4            2  1598976072704          10        300  XPLAYER         11
#
#     role_1  player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 2  xplayer  OPHYPERB              50  oplayer    CHEAT              50
# 3  xplayer  OPHYPERB              50  oplayer    CHEAT              50
# 4  xplayer  OPHYPERB               0  oplayer    CHEAT             100
#                                           match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1598975661576          10        300  XPLAYER          8
# 1            2  1598975883714          10        300  XPLAYER          7
# 2            2  1598976196375          10        300  XPLAYER          9
# 3            2  1598976408973          10        300  XPLAYER          6
# 4            2  1598976571626          10        300  XPLAYER          5
#
#     role_1  player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 2  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPERB             100  oplayer    CHEAT               0
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1598975922266          10        300  XPLAYER          5
# 1            2  1598976540390          10        300  XPLAYER          6
# 2            2  1598977295101          10        300  XPLAYER          7
# 3            2  1598977734363          10        300  XPLAYER          4
# 4            2  1598978527813          10        300  XPLAYER          9
#
#     role_1  player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPERB             100  oplayer    CHEAT               0
# 1  xplayer  OPHYPERB              50  oplayer    CHEAT              50
# 2  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPERB               0  oplayer    CHEAT             100
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1598976796922          10        300  XPLAYER          6
# 1            2  1598978333967          10        300  XPLAYER          6
# 2            2  1598980170554          10        300  XPLAYER          7
# 3            2  1598981408701          10        300  XPLAYER          5
# 4            2  1598982647109          10        300  XPLAYER          5
#
#     role_1  player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPERB             100  oplayer    CHEAT               0
# 2  xplayer  OPHYPERB             100  oplayer    CHEAT               0
# 3  xplayer  OPHYPERB             100  oplayer    CHEAT               0
# 4  xplayer  OPHYPERB             100  oplayer    CHEAT               0

# %% [markdown]
# Next, the move data should be read in for each match
#
# *Note: time_to_update and time_to_select_move are in milliseconds*

# %%
move_list_games = list()
for idx, name in enumerate(numNames):
    file_name_prefix = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ophyperb_resources/' + name + '/moveset/'
    temp_move_list = list()
    for match_name in data[idx]['match_id']:
        file_name = file_name_prefix + match_name + '.csv'
        temp_move_list.append(pd.read_csv(file_name))
    move_list_games.append(temp_move_list)

move_list_games_ahyper = list()
for idx, name in enumerate(numNames):
    file_name_prefix = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ahyperlt_resources/' + name + '/moveset/'
    temp_move_list = list()
    for match_name in data_ahyper[idx]['match_id']:
        file_name = file_name_prefix + match_name + '.csv'
        temp_move_list.append(pd.read_csv(file_name, names=['match_id','game_name','step','role_name','player_name','count_hypergames','num_probes','time_to_update','time_to_select_move','move_chosen','last_move_illegal','numTimesMovesSimulated','numTimesHypergameForward']))
    move_list_games_ahyper.append(temp_move_list)
    
# Verify by printing the head of the first game
for move_list in move_list_games:
    display(move_list[0])
# Out:
#                                            match_id           game_name  step  \
# 0   kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     0
# 1   kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     0
# 2   kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     1
# 3   kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     1
# 4   kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     2
# 5   kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     2
# 6   kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     3
# 7   kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     3
# 8   kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     4
# 9   kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     4
# 10  kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     5
# 11  kriegTTT_5x5_CHEAT_2x2ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     5
#
#    role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0    XPLAYER    ophyperb                 1           2              13
# 1    OPLAYER       cheat                 1          16              16
# 2    XPLAYER    ophyperb                 2           2              29
# 3    OPLAYER       cheat                 1          16              85
# 4    XPLAYER    ophyperb                 2           2              27
# 5    OPLAYER       cheat                 1          16              51
# 6    XPLAYER    ophyperb                 2           2              14
# 7    OPLAYER       cheat                 1          16              15
# 8    XPLAYER    ophyperb                 2           2               9
# 9    OPLAYER       cheat                 1          16              48
# 10   XPLAYER    ophyperb                 2           2              66
# 11   OPLAYER       cheat                 1          16              43
#
#     time_to_select_move  move_chosen  last_move_illegal  num_sims  \
# 0                  4013  (MARK 1 4 )              False        50
# 1                 14302  (MARK 5 5 )              False       375
# 2                  5872  (MARK 3 4 )              False        96
# 3                 13047  (MARK 4 3 )              False       360
# 4                  4712  (MARK 3 1 )              False        92
# 5                 10605  (MARK 2 4 )              False       345
# 6                  4063  (MARK 4 4 )              False        88
# 7                  9956  (MARK 3 3 )              False       330
# 8                  2828  (MARK 2 1 )              False        84
# 9                  8807  (MARK 2 3 )              False       315
# 10                 2579  (MARK 5 2 )              False        80
# 11                 5354  (MARK 5 3 )              False       300
#
#     num_forward_calls
# 0                   0
# 1                   0
# 2                   2
# 3                  18
# 4                   2
# 5                  16
# 6                   2
# 7                   5
# 8                   2
# 9                  19
# 10                 25
# 11                 19
#                                            match_id           game_name  step  \
# 0   kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     0
# 1   kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     0
# 2   kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     1
# 3   kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     1
# 4   kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     2
# 5   kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     2
# 6   kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     3
# 7   kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     3
# 8   kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     4
# 9   kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     4
# 10  kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     5
# 11  kriegTTT_5x5_CHEAT_4x4ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     5
#
#    role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0    XPLAYER    ophyperb                 1           4               8
# 1    OPLAYER       cheat                 1          16              20
# 2    OPLAYER       cheat                 1          16              69
# 3    XPLAYER    ophyperb                 4           4              55
# 4    OPLAYER       cheat                 1          16              32
# 5    XPLAYER    ophyperb                 4           4              20
# 6    XPLAYER    ophyperb                 3           4            2464
# 7    OPLAYER       cheat                 1          16              52
# 8    OPLAYER       cheat                 1          16              43
# 9    XPLAYER    ophyperb                 4           4            1129
# 10   OPLAYER       cheat                 1          16              25
# 11   XPLAYER    ophyperb                 4           4              13
#
#     time_to_select_move  move_chosen  last_move_illegal  num_sims  \
# 0                  7694  (MARK 2 4 )              False       100
# 1                 16552  (MARK 4 1 )              False       375
# 2                 19680  (MARK 2 2 )              False       360
# 3                 21489  (MARK 3 4 )              False       384
# 4                 18143  (MARK 3 2 )              False       345
# 5                 18564  (MARK 4 1 )              False       368
# 6                 13147  (MARK 4 4 )              False       264
# 7                 16255  (MARK 4 4 )              False       330
# 8                 15817  (MARK 5 2 )              False       315
# 9                 15494  (MARK 4 5 )              False       336
# 10                12051  (MARK 4 2 )              False       315
# 11                12890  (MARK 5 1 )              False       352
#
#     num_forward_calls
# 0                   0
# 1                   0
# 2                  13
# 3                   4
# 4                  11
# 5                   4
# 6                 930
# 7                  13
# 8                  19
# 9                 480
# 10                 12
# 11                  4
#                                            match_id           game_name  step  \
# 0   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     0
# 1   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     0
# 2   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     1
# 3   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     1
# 4   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     2
# 5   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     2
# 6   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     3
# 7   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     3
# 8   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     4
# 9   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     4
# 10  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     5
# 11  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     5
# 12  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     6
# 13  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     6
# 14  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     7
# 15  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT     7
#
#    role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0    XPLAYER    ophyperb                 1           8              34
# 1    OPLAYER       cheat                 1          16              21
# 2    OPLAYER       cheat                 1          16               8
# 3    XPLAYER    ophyperb                 8           8              71
# 4    OPLAYER       cheat                 1          16              78
# 5    XPLAYER    ophyperb                 8           8              50
# 6    OPLAYER       cheat                 1          16              49
# 7    XPLAYER    ophyperb                 8           8              43
# 8    OPLAYER       cheat                 1          16              63
# 9    XPLAYER    ophyperb                 8           8            1113
# 10   OPLAYER       cheat                 1          16              31
# 11   XPLAYER    ophyperb                 8           8            1062
# 12   OPLAYER       cheat                 1          16              26
# 13   XPLAYER    ophyperb                 8           8             885
# 14   OPLAYER       cheat                 1          16              36
# 15   XPLAYER    ophyperb                 7           8           27884
#
#     time_to_select_move  move_chosen  last_move_illegal  num_sims  \
# 0                 13205  (MARK 1 3 )              False       200
# 1                 17369  (MARK 5 2 )              False       375
# 2                 18653  (MARK 3 2 )              False       360
# 3                 46684  (MARK 2 2 )              False      1536
# 4                 17948  (MARK 3 5 )              False       345
# 5                 41169  (MARK 5 3 )              False      1472
# 6                 16134  (MARK 4 1 )              False       330
# 7                 37067  (MARK 4 2 )              False      1408
# 8                 14568  (MARK 5 4 )              False       315
# 9                 31553  (MARK 2 4 )              False      1344
# 10                12072  (MARK 2 3 )              False       300
# 11                28574  (MARK 2 1 )              False      1280
# 12                12955  (MARK 3 4 )              False       285
# 13                23735  (MARK 3 5 )              False      1216
# 14                 9668  (MARK 3 3 )              False       270
# 15                 9357  (MARK 2 3 )              False      1008
#
#     num_forward_calls
# 0                   0
# 1                   0
# 2                   1
# 3                   9
# 4                  22
# 5                   8
# 6                  15
# 7                  10
# 8                  22
# 9                 540
# 10                 13
# 11                497
# 12                 13
# 13                454
# 14                 18
# 15              28298
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 5  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 6  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 7  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 8  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 9  kriegTTT_5x5_CHEAT_16x16ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
#
#    step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0     0   OPLAYER       cheat                 1          16              10
# 1     0   XPLAYER    ophyperb                 1          16               5
# 2     1   OPLAYER       cheat                 1          16              53
# 3     1   XPLAYER    ophyperb                16          16             139
# 4     2   OPLAYER       cheat                 1          16              24
# 5     2   XPLAYER    ophyperb                16          16             106
# 6     3   OPLAYER       cheat                 1          16              29
# 7     3   XPLAYER    ophyperb                16          16             309
# 8     4   OPLAYER       cheat                 1          16              70
# 9     4   XPLAYER    ophyperb                16          16            3246
#
#    time_to_select_move  move_chosen  last_move_illegal  num_sims  \
# 0                23966  (MARK 1 4 )              False       375
# 1                24505  (MARK 4 4 )              False       400
# 2                20228  (MARK 3 3 )              False       360
# 3               159853  (MARK 4 2 )              False      6144
# 4                15324  (MARK 4 3 )              False       345
# 5               130421  (MARK 4 3 )              False      5888
# 6                15320  (MARK 5 3 )              False       330
# 7               125098  (MARK 4 5 )              False      5632
# 8                12272  (MARK 5 4 )              False       330
# 9                99325  (MARK 4 3 )              False      5632
#
#    num_forward_calls
# 0                  0
# 1                  0
# 2                  7
# 3                 16
# 4                  5
# 5                 16
# 6                  9
# 7                111
# 8                 19
# 9               1107
#                                              match_id           game_name  \
# 0   kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 1   kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 2   kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 3   kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 4   kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 5   kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 6   kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 7   kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 8   kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 9   kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 10  kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
# 11  kriegTTT_5x5_CHEAT_32x32ophyperb_16cheat_linear_0  kriegTTT_5x5_CHEAT
#
#     step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0      0   OPLAYER       cheat                 1          16              15
# 1      0   XPLAYER    ophyperb                 1          32               6
# 2      1   OPLAYER       cheat                 1          16             119
# 3      1   XPLAYER    ophyperb                24          17             201
# 4      2   OPLAYER       cheat                 1          16              36
# 5      2   XPLAYER    ophyperb                32          16             289
# 6      3   OPLAYER       cheat                 1          16              76
# 7      3   XPLAYER    ophyperb                32          25            1454
# 8      4   OPLAYER       cheat                 1          16              22
# 9      4   XPLAYER    ophyperb                32          22           17169
# 10     5   OPLAYER       cheat                 1          16              22
# 11     5   XPLAYER    ophyperb                 8          32           30012
#
#     time_to_select_move  move_chosen  last_move_illegal  num_sims  \
# 0                 24907  (MARK 2 2 )              False       375
# 1                 38656  (MARK 2 4 )              False       800
# 2                 22250  (MARK 5 4 )              False       360
# 3                298804  (MARK 4 4 )              False      9570
# 4                 18793  (MARK 5 5 )              False       345
# 5                298735  (MARK 3 4 )              False     11233
# 6                 14330  (MARK 1 4 )              False       330
# 7                297569  (MARK 5 4 )              False     17480
# 8                 16064  (MARK 5 2 )              False       315
# 9                281835  (MARK 1 4 )              False     14408
# 10                 9668  (MARK 5 3 )              False       300
# 11               115348  (MARK 4 3 )              False      5120
#
#     num_forward_calls
# 0                   0
# 1                   0
# 2                  22
# 3                  25
# 4                   7
# 5                  66
# 6                  21
# 7                 635
# 8                  11
# 9                7662
# 10                  8
# 11              22375

# %% [markdown]
# ## Analysis of Data
#
# ### Overall Agent Results
#
# The average score of the agent will be calculated across all games

# %%
count_games_completed = list()
total_score_ophyper = list()
for idx, game in enumerate(data):
    total_score = data[idx]['player_1_score'][data[idx]['player_1_score'] >= 50].count() * 100
    total_count = len(data[idx]['player_1_score'])
    count_games_completed.append(total_count)
    total_score_ophyper.append(total_score)
    print(f"The win/draw rate for the agent \"" + str(data[idx]['player_1'][0]) + "\" playing the game \"" + str(data[idx]['game_name'][0]) + "\" with " + str(numNames[idx]) + f" probes is {(total_score/total_count):.2f}% for " + str(total_count) + " games")

# calc results for ahyper
win_count_ahyper = list()
total_score_ahyper = list()
for idx, game in enumerate(data_ahyper):
    total_score = data_ahyper[idx]['player_1_score'][data_ahyper[idx]['player_1_score'] >= 50].count() * 100
    total_score_ahyper.append(total_score)
    game_count = [len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 0)]), len(game[(game['player_1_score'] == 0) & (game['player_2_score'] == 100)]), len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)])]
    win_count_ahyper.append(game_count[0])
    
# Display a pie chart
fig = plt.figure()
data_len = len(data)
win_count = list()
for idx, game in enumerate(data):
    ax = fig.add_axes([(data_len - idx)%2,math.ceil((data_len - idx)/2),1,1])
    ax.axis('equal')
    ax.set_title('Win rate for ' + str(numNames[idx]))
    result = ['Won', 'Lost', 'Drew']
    game_count = [len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 0)]), len(game[(game['player_1_score'] == 0) & (game['player_2_score'] == 100)]), len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)])]
    win_count.append(game_count[0])
    ax.pie(game_count, labels = result,autopct='%1.1f%%')
plt.show()
# Out:
# The win/draw rate for the agent "OPHYPERB" playing the game "kriegTTT_5x5_CHEAT" with 2x2 probes is 6.00% for 100 games
# The win/draw rate for the agent "OPHYPERB" playing the game "kriegTTT_5x5_CHEAT" with 4x4 probes is 22.00% for 100 games
# The win/draw rate for the agent "OPHYPERB" playing the game "kriegTTT_5x5_CHEAT" with 8x8 probes is 40.00% for 100 games
# The win/draw rate for the agent "OPHYPERB" playing the game "kriegTTT_5x5_CHEAT" with 16x16 probes is 66.00% for 100 games
# The win/draw rate for the agent "OPHYPERB" playing the game "kriegTTT_5x5_CHEAT" with 32x32 probes is 77.00% for 100 games

# %% [markdown]
# It is now worth looking into how performance degrades with fewer probes.
#
# First I will consider the number of games that can be completed without error compared to the number of probes.

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2], label='state_update')
ax1.set_title('Number of Games Completed')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Games Completed')
ax1.set_yscale('linear')
ax1.set_ylim([0,101])
ax1.bar(numNames, count_games_completed, color=u'#ff7f0e')
plt.show()

# %% [markdown]
# I will now consider whether the number of games won

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Proportion of Games Won that were Completed')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Games Won')
ax1.set_yscale('linear')
ax1.set_yticks(np.linspace(0, 100, 21))
ax1.set_ylim([0,100])
nobias_line, = ax1.plot(numNames, np.divide(total_score_ophyper,count_games_completed), marker='o', color=u'#ff7f0e')
plt.show()

# %% [markdown]
# Compared to ahyperlt

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Overall Score Against Number of Resources')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Overall Score')
ax1.set_yscale('linear')
ax1.set_yticks(np.linspace(0, 100, 21))
ax1.set_ylim([0,100])
ahyper_line, = ax1.plot(numNames, np.divide(total_score_ahyper,count_games_completed), marker='o')
nobias_line, = ax1.plot(numNames, np.divide(total_score_ophyper,count_games_completed), marker='o')
ax1.legend((nobias_line, ahyper_line), ('Opponent Modelling - True Dist', 'Original Hyperplay'))
plt.show()

# %% [markdown]
# ### Move Results
#
# Calculating the average move time per game.
# This is expected to grow with the depth of the game and is expected to be different for the state update and the move selection.

# %%
class Tracker:
    '''
    Tracker tracks the average time for each move of each game played
    '''
    def __init__(self):
        self.time_sum = 0
        self.num_moves = 0
        self.times = list()
    
    def __str__(self):
        return "time_sum: " + str(self.time_sum) + " ms\n\tnum_moves: " + str(self.num_moves) + "\n\tmean_time: " + str(statistics.mean(self.times)) + "\n\tmedian_time: " + str(statistics.median(self.times)) + " ms\n\ttimes (ms): " + str(self.times)
    
    def addMove(self, num):
        self.time_sum += num
        self.num_moves+=1
        self.times.append(num)
    
    def getMeanTime(self):
        return statistics.mean(self.times)
    
    def getMedianTime(self):
        return statistics.median(self.times)

# Add the results for each move of each game played to a list of trackers for the update and select move times for the chosen player
time_to_update_list = list()
time_to_select_move_list = list()
max_num_steps = [0] * len(numNames)
for idx, (move_list, game) in enumerate(zip(move_list_games, data)):
    temp_time_to_update_list = list()
    temp_time_to_select_move_list = list()
    player_name = game['role_1'][0].upper()
    for move_set in move_list:
        for index, move_row in move_set.iterrows():
            if move_row['role_name'] == player_name:
                if move_row['step'] > len(temp_time_to_update_list) - 1:
                    max_num_steps[idx] += 1
                    temp_time_to_update_list.append(Tracker())
                    temp_time_to_select_move_list.append(Tracker())
                temp_time_to_update_list[move_row['step']].addMove(move_row['time_to_update'])
                temp_time_to_select_move_list[move_row['step']].addMove(move_row['time_to_select_move'])
    time_to_update_list.append(temp_time_to_update_list)
    time_to_select_move_list.append(temp_time_to_select_move_list)

# Print the data
for game_num, (game_time_to_update_list, game_time_to_select_move_list) in enumerate(zip(time_to_update_list, time_to_select_move_list)):
    print(str(numNames[game_num]))
    for idx, (update_step, select_step) in enumerate(zip(game_time_to_update_list, game_time_to_select_move_list)):
        print('\tStep: ' + str(idx) + "\n")
        print('\tTime taken to update states:')
        print('\t' + str(update_step)  + "\n")
        print('\tTime taken to select move:')
        print('\t' + str(select_step)  + "\n\n\n")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-007226e4a269> in <module>
#      37                     temp_time_to_update_list.append(Tracker())
#      38                     temp_time_to_select_move_list.append(Tracker())
# ---> 39                 temp_time_to_update_list[move_row['step']].addMove(move_row['time_to_update'])
#      40                 temp_time_to_select_move_list[move_row['step']].addMove(move_row['time_to_select_move'])
#      41     time_to_update_list.append(temp_time_to_update_list)
#
# IndexError: list index out of range

# %% [markdown]
# Now I will graph the findings

# %%
# Add the data to an array
mean_state_update_times = list()
mean_move_select_times = list()
median_state_update_times = list()
median_move_select_times = list()
for game_num, (game_time_to_update_list, game_time_to_select_move_list) in enumerate(zip(time_to_update_list, time_to_select_move_list)):
    temp_mean_state_update_times = list()
    temp_mean_move_select_times = list()
    temp_median_state_update_times = list()
    temp_median_move_select_times = list()
    for update_step, select_step in zip(game_time_to_update_list, game_time_to_select_move_list):
        temp_mean_state_update_times.append(update_step.getMeanTime())
        temp_mean_move_select_times.append(select_step.getMeanTime())
        temp_median_state_update_times.append(update_step.getMedianTime())
        temp_median_move_select_times.append(select_step.getMedianTime())
    mean_state_update_times.append(temp_mean_state_update_times)
    mean_move_select_times.append(temp_mean_move_select_times)
    median_state_update_times.append(temp_median_state_update_times)
    median_move_select_times.append(temp_median_move_select_times)

# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.5, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,1.25,1,1], label='state_update_mean')
ax1.set_title('Mean Time Taken to Update State Against Step Number')
ax1.set_xlabel('Steps')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
for idx, game_mean_state_update_times in enumerate(mean_state_update_times):
    ax1.plot(game_mean_state_update_times, label=str(numNames[idx]))
ax1.legend()

# Draw mean graph for Move Select
ax2 = fig.add_axes([1.15,1.25,1,1], label='move_select_mean')
ax2.set_title('Mean Time Taken to Select Move Against Step Number')
ax2.set_xlabel('Steps')
ax2.set_ylabel('Time (ms)')
ax2.set_yscale('linear')
for idx, game_mean_move_select_times in enumerate(mean_move_select_times):
    ax2.plot(game_mean_move_select_times, label=str(numNames[idx]))
ax2.legend()

# Draw median graph for State Update
ax3 = fig.add_axes([0,0,1,1], label='state_update_median')
ax3.set_title('Median Time Taken to Update State Against Step Number')
ax3.set_xlabel('Steps')
ax3.set_ylabel('Time (ms)')
ax3.set_yscale('log')
for idx, game_median_state_update_times in enumerate(median_state_update_times):
    ax3.plot(game_median_state_update_times, label=str(numNames[idx]))
ax3.legend()

# Draw median graph for Move Select
ax4 = fig.add_axes([1.15,0,1,1], label='move_select_median')
ax4.set_title('Median Time Taken to Select Move Against Step Number')
ax4.set_xlabel('Steps')
ax4.set_ylabel('Time (ms)')
ax4.set_yscale('linear')
for idx, game_median_move_select_times in enumerate(median_move_select_times):
    ax4.plot(game_median_move_select_times, label=str(numNames[idx]))
ax4.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
sum_game_median_state_update_times = list()
for idx, game_median_state_update_times in enumerate(median_state_update_times):
    sum_game_median_state_update_times.append(sum(game_median_state_update_times)/len(game_median_state_update_times))
    
# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.15, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Median Time Taken to Update State')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
ax1.set_ylim([1,100000])
ax1.bar(numNames, sum_game_median_state_update_times)

plt.show()
    
# sum_game_mean_state_update_times
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-37881f15e981> in <module>
#      14 ax1.set_yscale('log')
#      15 ax1.set_ylim([1,100000])
# ---> 16 ax1.bar(numNames, sum_game_median_state_update_times)
#      17
#      18 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# ~\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     257     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     258
# --> 259     shape = _broadcast_shape(*args)
#     260
#     261     if all(array.shape == shape for array in args):
#
# ~\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     191     # use the old-iterator because np.nditer does not handle size 0 arrays
#     192     # consistently
# --> 193     b = np.broadcast(*args[:32])
#     194     # unfortunately, it cannot handle 32 or more arguments directly
#     195     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
sum_game_median_move_select_times = list()
for idx, game_median_move_select_times in enumerate(median_move_select_times):
    sum_game_median_move_select_times.append(sum(game_median_move_select_times)/len(game_median_move_select_times))
    
# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.15, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Median Time Taken to Select Move')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
ax1.set_ylim([1,100000])
ax1.bar(numNames, sum_game_median_move_select_times)

plt.show()
    
# sum_game_mean_state_update_times

# %% [markdown]
# ## Hypergame Utilization
#
# I will now consider how useful increasing the cap of hypergames was

# %%
max_hypergames = [2, 4, 8, 16, 32]

hypergame_utilization_sum = list()
hypergame_utilization_max = list()
hypergame_utilization_count = list()
hypergame_utilization = list()

fig = plt.figure()

for idx, move_list in enumerate(move_list_games):
    hypergame_utilization_sum.append([0] * max_num_steps[idx])
    hypergame_utilization_max.append([0] * max_num_steps[idx])
    hypergame_utilization_count.append([0] * max_num_steps[idx])
    hypergame_utilization.append([])

    # Count number of hypergames used on average at each step out of the maximum number
    for game in move_list:
        for index, row in game.iterrows():
            if(row['player_name'] == 'ophyperb'):
                hypergame_utilization_sum[idx][row['step']] += row['count_hypergames']
                hypergame_utilization_count[idx][row['step']] += 1
                if(row['count_hypergames'] / max_hypergames[idx] > hypergame_utilization_max[idx][row['step']]):
                    hypergame_utilization_max[idx][row['step']] = row['count_hypergames'] / max_hypergames[idx]
    hypergame_utilization[idx] = [(utilSum / count) / max_hypergames[idx] for utilSum, count in zip(hypergame_utilization_sum[idx], hypergame_utilization_count[idx])]

    # display
    
    ax1 = fig.add_axes([0,-idx - idx*0.25,1,1])
    ax1.set_title('Average proportion of hypergame usage at each step for ' + str(numNames[idx]))
    ax1.set_xlabel('Step')
    ax1.set_ylabel('Hypergame usage out of max of ' + str(max_hypergames[idx]))
    ax1.set_yscale('linear')
    ax1.set_yticks(np.linspace(0,1,11))
    ax1.set_ylim([0,1])
    ax1.bar(range(0, len(hypergame_utilization[idx])), hypergame_utilization[idx])

    ax2 = fig.add_axes([1.25,-idx  - idx*0.25,1,1])
    ax2.set_title('Maximum hypergame usage at each step for ' + str(numNames[idx]))
    ax2.set_xlabel('Step')
    ax2.set_ylabel('Hypergame usage out of max of ' + str(max_hypergames[idx]))
    ax2.set_yscale('linear')
    ax2.set_yticks(np.linspace(0,1,11))
    ax2.set_ylim([0,1])
    ax2.bar(range(0, len(hypergame_utilization_max[idx])), hypergame_utilization_max[idx])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-51d079dfa68c> in <module>
#      18         for index, row in game.iterrows():
#      19             if(row['player_name'] == 'ophyperb'):
# ---> 20                 hypergame_utilization_sum[idx][row['step']] += row['count_hypergames']
#      21                 hypergame_utilization_count[idx][row['step']] += 1
#      22                 if(row['count_hypergames'] / max_hypergames[idx] > hypergame_utilization_max[idx][row['step']]):
#
# IndexError: list index out of range

# %% [markdown]
# ### Steps taken to win

# %%
# Calculate the average number of steps taken to win for each hypergame
steps_to_win_list = list()
for idx, (move_list, game) in enumerate(zip(move_list_games, data)):
    game_steps_to_win_list = list()
    winning_games = game[((game['player_1_score'] == 100) & (game['player_2_score'] == 0)) | (len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)]))] 
    winning_games_list = winning_games['match_id'].tolist()
    for moves in move_list:
        if(moves['match_id'][0] in winning_games_list):
            move_length = len(moves['match_id'])
            game_steps_to_win_list.append(moves['step'][move_length - 1] + 1)
    steps_to_win_list.append(game_steps_to_win_list)

# Print steps to win
mean_steps_to_win = list()
median_steps_to_win = list()
for idx, game_steps_to_win in enumerate(steps_to_win_list):
    mean = statistics.mean(game_steps_to_win)
    median = statistics.median(game_steps_to_win)
    print(f'{numNames[idx]}')
    print(f'\tMean steps to win: {mean}')
    print(f'\tMedian steps to win: {median}')
    mean_steps_to_win.append(mean)
    median_steps_to_win.append(median)

# Graph steps to win
fig = plt.figure()
ax1 = fig.add_axes([0,0,1.75,1.5])
ax1.set_title('Mean Number of Steps Taken to Win')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Steps')
ax1.set_yscale('linear')
ax1.set_yticks(range(0,36,1))
ax1.set_ylim([0,36])
ax1.bar(numNames, mean_steps_to_win)

ax2 = fig.add_axes([0,-1.75,1.75,1.5])
ax2.set_title('Median Number of Steps Taken to Win')
ax2.set_xlabel('Agent')
ax2.set_ylabel('Steps')
ax2.set_yscale('linear')
ax2.set_yticks(range(0,36,1))
ax2.set_ylim([0,36])
ax2.bar(numNames, median_steps_to_win)

plt.show()
# Out:
# 2x2
# 	Mean steps to win: 6
# 	Median steps to win: 6.0
# 4x4
# 	Mean steps to win: 7
# 	Median steps to win: 6.0
# 8x8
# 	Mean steps to win: 6
# 	Median steps to win: 6.0
# 16x16
# 	Mean steps to win: 6
# 	Median steps to win: 5.0
# 32x32
# 	Mean steps to win: 5
# 	Median steps to win: 5.0
