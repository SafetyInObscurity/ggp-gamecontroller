# %% [markdown]
# # <center>OP Hyper Bias Power</center>
#
# This file is an interactive notebook to analyze the data obtained from tests.<br>
# The purpose of this notebook is to define a baseline for a model which can be improved upon.
# The game blind_breakthrough will be used since this seems to be the game the original hyperplay model performed the best at.
#
# **Note: It could be a good idea to look into using a stronger cheat agent for a better comparison**
#
# ## Reading in the Data
#
# First the match data must be read in.
# I will be reading in data obtained for a series of games where a hyperplayer with increasing resources competed against a CHEAT player who had access to the true state and was allowed 16 simulations per move.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import statistics
np.random.seed(42)

# Read in the csv files
numNames = ['half', '1', '1half', '2', '2half', '3']
data = list()

for idx, name in enumerate(numNames):
    file_name = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ophyperb_power/' + name + '/testOutput.csv'
    data.append(pd.DataFrame)
    data[idx] = pd.read_csv(file_name, header=0)

# Read in the csv files
numNamesAhyper = ['2x2', '4x4', '8x8', '16x16', '32x32']
data_ahyper = list()

for idx, name in enumerate(numNamesAhyper):
    file_name = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ahyperlt_resources/' + name + '/testOutput.csv'
    data_ahyper.append(pd.DataFrame)
    data_ahyper[idx] = pd.read_csv(file_name, header=0)
    
# Print the first 5 rows of the data
for game in data:
    display(game.head())
# Out:
#                                         match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1599008193198          10        300  XPLAYER          4
# 1            2  1599008493193          10        300  XPLAYER          8
# 2            2  1599008765591          10        300  XPLAYER          7
# 3            2  1599009006004          10        300  XPLAYER          6
# 4            2  1599009198410          10        300  XPLAYER          5
#
#     role_1  player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 2  xplayer  OPHYPERB             100  oplayer    CHEAT               0
# 3  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPERB              50  oplayer    CHEAT              50
#                                      match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1599008346090          10        300  XPLAYER          9
# 1            2  1599008530192          10        300  XPLAYER          5
# 2            2  1599008856557          10        300  XPLAYER         10
# 3            2  1599009065380          10        300  XPLAYER          6
# 4            2  1599009276334          10        300  XPLAYER          6
#
#     role_1  player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPERB             100  oplayer    CHEAT               0
# 2  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPERB              50  oplayer    CHEAT              50
#                                          match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1599008433921          10        300  XPLAYER         10
# 1            2  1599008663890          10        300  XPLAYER          6
# 2            2  1599008982453          10        300  XPLAYER          9
# 3            2  1599009194295          10        300  XPLAYER          5
# 4            2  1599009405394          10        300  XPLAYER          5
#
#     role_1  player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPERB              50  oplayer    CHEAT              50
# 2  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPERB               0  oplayer    CHEAT             100
#                                      match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1599008238327          10        300  XPLAYER          6
# 1            2  1599008482615          10        300  XPLAYER          7
# 2            2  1599008720225          10        300  XPLAYER          7
# 3            2  1599008888859          10        300  XPLAYER          5
# 4            2  1599009093425          10        300  XPLAYER          6
#
#     role_1  player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 2  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPERB              50  oplayer    CHEAT              50
# 4  xplayer  OPHYPERB             100  oplayer    CHEAT               0
#                                          match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1599008182401          10        300  XPLAYER          4
# 1            2  1599008463920          10        300  XPLAYER          7
# 2            2  1599008675136          10        300  XPLAYER          5
# 3            2  1599008849185          10        300  XPLAYER          4
# 4            2  1599009056931          10        300  XPLAYER          5
#
#     role_1  player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPERB             100  oplayer    CHEAT               0
# 1  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 2  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPERB             100  oplayer    CHEAT               0
#                                      match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1599008226581          10        300  XPLAYER          6
# 1            2  1599008372202          10        300  XPLAYER          4
# 2            2  1599008639774          10        300  XPLAYER          7
# 3            2  1599008856448          10        300  XPLAYER          6
# 4            2  1599009090057          10        300  XPLAYER          7
#
#     role_1  player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPERB             100  oplayer    CHEAT               0
# 1  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 2  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPERB               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPERB             100  oplayer    CHEAT               0

# %% [markdown]
# Next, the move data should be read in for each match
#
# *Note: time_to_update and time_to_select_move are in milliseconds*

# %%
move_list_games = list()
for idx, name in enumerate(numNames):
    file_name_prefix = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ophyperb_power/' + name + '/moveset/'
    temp_move_list = list()
    for match_name in data[idx]['match_id']:
        file_name = file_name_prefix + match_name + '.csv'
        temp_move_list.append(pd.read_csv(file_name))
    move_list_games.append(temp_move_list)

move_list_games_ahyper = list()
for idx, name in enumerate(numNamesAhyper):
    file_name_prefix = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ahyperlt_resources/' + name + '/moveset/'
    temp_move_list = list()
    for match_name in data_ahyper[idx]['match_id']:
        file_name = file_name_prefix + match_name + '.csv'
        temp_move_list.append(pd.read_csv(file_name, names=['match_id','game_name','step','role_name','player_name','count_hypergames','num_probes','time_to_update','time_to_select_move','move_chosen','last_move_illegal','numTimesMovesSimulated','numTimesHypergameForward']))
    move_list_games_ahyper.append(temp_move_list)
    
# Verify by printing the head of the first game
for move_list in move_list_games:
    display(move_list[0])
# Out:
#                                         match_id           game_name  step  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_0  kriegTTT_5x5_CHEAT     0
# 1  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_0  kriegTTT_5x5_CHEAT     0
# 2  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_0  kriegTTT_5x5_CHEAT     1
# 3  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_0  kriegTTT_5x5_CHEAT     1
# 4  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_0  kriegTTT_5x5_CHEAT     2
# 5  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_0  kriegTTT_5x5_CHEAT     2
# 6  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_0  kriegTTT_5x5_CHEAT     3
# 7  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_half_0  kriegTTT_5x5_CHEAT     3
#
#   role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0   XPLAYER    ophyperb                 1           8              10
# 1   OPLAYER       cheat                 1          16              27
# 2   OPLAYER       cheat                 1          16              62
# 3   XPLAYER    ophyperb                 8           8              68
# 4   OPLAYER       cheat                 1          16              75
# 5   XPLAYER    ophyperb                 8           8              48
# 6   OPLAYER       cheat                 1          16               7
# 7   XPLAYER    ophyperb                 8           8              91
#
#    time_to_select_move  move_chosen  last_move_illegal  num_sims  \
# 0                13682  (MARK 2 3 )              False       200
# 1                19424  (MARK 4 1 )              False       375
# 2                19897  (MARK 3 1 )              False       360
# 3                55322  (MARK 3 2 )              False      1536
# 4                16888  (MARK 2 1 )              False       345
# 5                49176  (MARK 1 2 )              False      1472
# 6                10501  (MARK 1 1 )              False       330
# 7                41032  (MARK 1 5 )              False      1408
#
#    num_forward_calls
# 0                  0
# 1                  0
# 2                 13
# 3                  8
# 4                 17
# 5                  8
# 6                  2
# 7                 33
#                                       match_id           game_name  step  \
# 0   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     0
# 1   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     0
# 2   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     1
# 3   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     1
# 4   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     2
# 5   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     2
# 6   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     3
# 7   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     3
# 8   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     4
# 9   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     4
# 10  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     5
# 11  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     5
# 12  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     6
# 13  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     6
# 14  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     7
# 15  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     7
# 16  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     8
# 17  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1_0  kriegTTT_5x5_CHEAT     8
#
#    role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0    XPLAYER    ophyperb                 1           8              18
# 1    OPLAYER       cheat                 1          16              19
# 2    OPLAYER       cheat                 1          16             127
# 3    XPLAYER    ophyperb                 8           8              40
# 4    OPLAYER       cheat                 1          16              27
# 5    XPLAYER    ophyperb                 8           8              67
# 6    OPLAYER       cheat                 1          16              50
# 7    XPLAYER    ophyperb                 8           8            1317
# 8    OPLAYER       cheat                 1          16              27
# 9    XPLAYER    ophyperb                 8           8           11861
# 10   OPLAYER       cheat                 1          16               6
# 11   XPLAYER    ophyperb                 8           8              62
# 12   OPLAYER       cheat                 1          16              36
# 13   XPLAYER    ophyperb                 2           8           30007
# 14   OPLAYER       cheat                 1          16              14
# 15   XPLAYER    ophyperb                 2           8           30012
# 16   OPLAYER       cheat                 1          16               7
# 17   XPLAYER    ophyperb                 2           8           30042
#
#     time_to_select_move  move_chosen  last_move_illegal  num_sims  \
# 0                 12659  (MARK 5 3 )              False       200
# 1                 17736  (MARK 2 5 )              False       375
# 2                 19621  (MARK 1 5 )              False       360
# 3                 47854  (MARK 5 2 )              False      1536
# 4                 15490  (MARK 5 4 )              False       345
# 5                 39384  (MARK 5 5 )              False      1472
# 6                 16089  (MARK 2 3 )              False       330
# 7                 31374  (MARK 5 4 )              False      1408
# 8                 15736  (MARK 3 2 )              False       315
# 9                 29322  (MARK 4 3 )              False      1344
# 10                13123  (MARK 1 2 )              False       300
# 11                32054  (MARK 2 5 )              False      1344
# 12                10028  (MARK 2 1 )              False       285
# 13                 5479  (MARK 2 1 )              False       320
# 14                 7953  (MARK 4 2 )              False       270
# 15                 4999  (MARK 3 1 )              False       304
# 16                 6470  (MARK 2 2 )              False       270
# 17                 4698  (MARK 3 3 )              False       320
#
#     num_forward_calls
# 0                   0
# 1                   0
# 2                  24
# 3                   8
# 4                   6
# 5                  11
# 6                  20
# 7                 587
# 8                  12
# 9                4461
# 10                  3
# 11                 32
# 12                 19
# 13              27317
# 14                  4
# 15              30121
# 16                  4
# 17              32143
#                                           match_id           game_name  step  \
# 0   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     0
# 1   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     0
# 2   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     1
# 3   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     1
# 4   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     2
# 5   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     2
# 6   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     3
# 7   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     3
# 8   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     4
# 9   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     4
# 10  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     5
# 11  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     5
# 12  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     6
# 13  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     6
# 14  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     7
# 15  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     7
# 16  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     8
# 17  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     8
# 18  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     9
# 19  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_1half_0  kriegTTT_5x5_CHEAT     9
#
#    role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0    XPLAYER    ophyperb                 1           8               5
# 1    OPLAYER       cheat                 1          16              20
# 2    OPLAYER       cheat                 1          16              48
# 3    XPLAYER    ophyperb                 8           8              56
# 4    OPLAYER       cheat                 1          16              84
# 5    XPLAYER    ophyperb                 8           8              48
# 6    OPLAYER       cheat                 1          16              58
# 7    XPLAYER    ophyperb                 8           8            1374
# 8    OPLAYER       cheat                 1          16              10
# 9    XPLAYER    ophyperb                 8           8              98
# 10   OPLAYER       cheat                 1          16              42
# 11   XPLAYER    ophyperb                 8           8            1337
# 12   OPLAYER       cheat                 1          16              28
# 13   XPLAYER    ophyperb                 8           8              83
# 14   OPLAYER       cheat                 1          16              47
# 15   XPLAYER    ophyperb                 8           8             141
# 16   OPLAYER       cheat                 1          16              12
# 17   XPLAYER    ophyperb                 2           8           30172
# 18   OPLAYER       cheat                 1          16              42
# 19   XPLAYER    ophyperb                 8           8           16503
#
#     time_to_select_move  move_chosen  last_move_illegal  num_sims  \
# 0                 14312  (MARK 1 2 )              False       200
# 1                 19672  (MARK 3 2 )              False       375
# 2                 21288  (MARK 2 3 )              False       360
# 3                 56982  (MARK 2 5 )              False      1536
# 4                 18251  (MARK 4 3 )              False       345
# 5                 50975  (MARK 1 3 )              False      1472
# 6                 14069  (MARK 1 4 )              False       330
# 7                 42274  (MARK 5 4 )              False      1408
# 8                 13768  (MARK 3 5 )              False       315
# 9                 38406  (MARK 3 4 )              False      1344
# 10                13302  (MARK 5 3 )              False       300
# 11                34805  (MARK 5 3 )              False      1280
# 12                13321  (MARK 4 2 )              False       285
# 13                34986  (MARK 4 2 )              False      1216
# 14                12823  (MARK 5 2 )              False       270
# 15                33112  (MARK 1 4 )              False      1152
# 16                12791  (MARK 4 2 )              False       285
# 17                 6436  (MARK 4 1 )              False       272
# 18                 6924  (MARK 2 2 )              False       270
# 19                31389  (MARK 4 3 )              False      1216
#
#     num_forward_calls
# 0                   0
# 1                   0
# 2                  10
# 3                   8
# 4                  24
# 5                   8
# 6                  21
# 7                 586
# 8                   5
# 9                  32
# 10                 16
# 11                520
# 12                 13
# 13                 34
# 14                 16
# 15                 44
# 16                  5
# 17              22888
# 18                 10
# 19              13366
#                                       match_id           game_name  step  \
# 0   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     0
# 1   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     0
# 2   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     1
# 3   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     1
# 4   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     2
# 5   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     2
# 6   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     3
# 7   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     3
# 8   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     4
# 9   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     4
# 10  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     5
# 11  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2_0  kriegTTT_5x5_CHEAT     5
#
#    role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0    XPLAYER    ophyperb                 1           8              14
# 1    OPLAYER       cheat                 1          16              35
# 2    OPLAYER       cheat                 1          16              53
# 3    XPLAYER    ophyperb                 8           8              63
# 4    OPLAYER       cheat                 1          16              69
# 5    XPLAYER    ophyperb                 8           8              60
# 6    OPLAYER       cheat                 1          16              17
# 7    XPLAYER    ophyperb                 8           8              46
# 8    OPLAYER       cheat                 1          16               2
# 9    XPLAYER    ophyperb                 8           8            3709
# 10   OPLAYER       cheat                 1          16              16
# 11   XPLAYER    ophyperb                 8           8             956
#
#     time_to_select_move  move_chosen  last_move_illegal  num_sims  \
# 0                 13308  (MARK 2 5 )              False       200
# 1                 17690  (MARK 2 3 )              False       375
# 2                 18831  (MARK 4 3 )              False       360
# 3                 46893  (MARK 1 4 )              False      1536
# 4                 15681  (MARK 1 2 )              False       345
# 5                 41868  (MARK 3 1 )              False      1472
# 6                 14343  (MARK 2 4 )              False       330
# 7                 37015  (MARK 5 4 )              False      1408
# 8                 12249  (MARK 2 2 )              False       315
# 9                 32106  (MARK 3 3 )              False      1344
# 10                10189  (MARK 2 1 )              False       300
# 11                29163  (MARK 2 3 )              False      1280
#
#     num_forward_calls
# 0                   0
# 1                   0
# 2                  11
# 3                   8
# 4                  14
# 5                   8
# 6                   5
# 7                   8
# 8                   1
# 9                1650
# 10                  9
# 11                497
#                                          match_id           game_name  step  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_0  kriegTTT_5x5_CHEAT     0
# 1  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_0  kriegTTT_5x5_CHEAT     0
# 2  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_0  kriegTTT_5x5_CHEAT     1
# 3  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_0  kriegTTT_5x5_CHEAT     1
# 4  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_0  kriegTTT_5x5_CHEAT     2
# 5  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_0  kriegTTT_5x5_CHEAT     2
# 6  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_0  kriegTTT_5x5_CHEAT     3
# 7  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_2half_0  kriegTTT_5x5_CHEAT     3
#
#   role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0   XPLAYER    ophyperb                 1           8               5
# 1   OPLAYER       cheat                 1          16               8
# 2   OPLAYER       cheat                 1          16              67
# 3   XPLAYER    ophyperb                 8           8              78
# 4   OPLAYER       cheat                 1          16              61
# 5   XPLAYER    ophyperb                 8           8              68
# 6   OPLAYER       cheat                 1          16              46
# 7   XPLAYER    ophyperb                 8           8            1468
#
#    time_to_select_move  move_chosen  last_move_illegal  num_sims  \
# 0                13995  (MARK 2 4 )              False       200
# 1                19410  (MARK 2 5 )              False       375
# 2                20097  (MARK 4 2 )              False       360
# 3                55613  (MARK 3 4 )              False      1536
# 4                16804  (MARK 3 1 )              False       345
# 5                46992  (MARK 4 4 )              False      1472
# 6                10855  (MARK 1 4 )              False       330
# 7                27664  (MARK 5 4 )              False      1408
#
#    num_forward_calls
# 0                  0
# 1                  0
# 2                 14
# 3                  8
# 4                 19
# 5                  8
# 6                 14
# 7                637
#                                       match_id           game_name  step  \
# 0   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     0
# 1   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     0
# 2   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     1
# 3   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     1
# 4   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     2
# 5   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     2
# 6   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     3
# 7   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     3
# 8   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     4
# 9   kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     4
# 10  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     5
# 11  kriegTTT_5x5_CHEAT_8x8ophyperb_16cheat_3_0  kriegTTT_5x5_CHEAT     5
#
#    role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0    XPLAYER    ophyperb                 1           8              17
# 1    OPLAYER       cheat                 1          16              16
# 2    OPLAYER       cheat                 1          16             109
# 3    XPLAYER    ophyperb                 8           8              60
# 4    OPLAYER       cheat                 1          16              42
# 5    XPLAYER    ophyperb                 8           8              56
# 6    OPLAYER       cheat                 1          16              37
# 7    XPLAYER    ophyperb                 8           8              42
# 8    OPLAYER       cheat                 1          16               7
# 9    XPLAYER    ophyperb                 8           8             132
# 10   OPLAYER       cheat                 1          16              43
# 11   XPLAYER    ophyperb                 8           8              52
#
#     time_to_select_move  move_chosen  last_move_illegal  num_sims  \
# 0                 13070  (MARK 2 5 )              False       200
# 1                 17387  (MARK 4 2 )              False       375
# 2                 19485  (MARK 3 3 )              False       360
# 3                 46907  (MARK 2 4 )              False      1536
# 4                 16064  (MARK 4 4 )              False       345
# 5                 40871  (MARK 2 3 )              False      1472
# 6                 11924  (MARK 2 2 )              False       330
# 7                 31836  (MARK 2 2 )              False      1408
# 8                 11699  (MARK 4 5 )              False       315
# 9                 29658  (MARK 4 3 )              False      1344
# 10                11591  (MARK 3 2 )              False       315
# 11                25797  (MARK 2 2 )              False      1344
#
#     num_forward_calls
# 0                   0
# 1                   0
# 2                  25
# 3                   8
# 4                  12
# 5                   8
# 6                  11
# 7                   8
# 8                   3
# 9                  48
# 10                 11
# 11                  9

# %% [markdown]
# ## Analysis of Data
#
# ### Overall Agent Results
#
# The average score of the agent will be calculated across all games

# %%
count_games_completed = list()
total_score_ophyper = list()
for idx, game in enumerate(data):
    total_score = data[idx]['player_1_score'][data[idx]['player_1_score'] >= 50].count() * 100
    total_count = len(data[idx]['player_1_score'])
    count_games_completed.append(total_count)
    total_score_ophyper.append(total_score)
    print(f"The win/draw rate for the agent \"" + str(data[idx]['player_1'][0]) + "\" playing the game \"" + str(data[idx]['game_name'][0]) + "\" with " + str(numNames[idx]) + f" probes is {(total_score/total_count):.2f}% for " + str(total_count) + " games")

# calc results for ahyper
win_count_ahyper = list()
total_score_ahyper = list()
for idx, game in enumerate(data_ahyper):
    total_score = data_ahyper[idx]['player_1_score'][data_ahyper[idx]['player_1_score'] >= 50].count() * 100
    total_score_ahyper.append(total_score)
    game_count = [len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 0)]), len(game[(game['player_1_score'] == 0) & (game['player_2_score'] == 100)]), len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)])]
    win_count_ahyper.append(game_count[0])
    
# Display a pie chart
fig = plt.figure()
data_len = len(data)
win_count = list()
for idx, game in enumerate(data):
    ax = fig.add_axes([(data_len - idx)%2,math.ceil((data_len - idx)/2),1,1])
    ax.axis('equal')
    ax.set_title('Win rate for ' + str(numNames[idx]))
    result = ['Won', 'Lost', 'Drew']
    game_count = [len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 0)]), len(game[(game['player_1_score'] == 0) & (game['player_2_score'] == 100)]), len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)])]
    win_count.append(game_count[0])
    ax.pie(game_count, labels = result,autopct='%1.1f%%')
plt.show()
# Out:
# The win/draw rate for the agent "OPHYPERB" playing the game "kriegTTT_5x5_CHEAT" with half probes is 50.00% for 100 games
# The win/draw rate for the agent "OPHYPERB" playing the game "kriegTTT_5x5_CHEAT" with 1 probes is 47.00% for 100 games
# The win/draw rate for the agent "OPHYPERB" playing the game "kriegTTT_5x5_CHEAT" with 1half probes is 41.00% for 100 games
# The win/draw rate for the agent "OPHYPERB" playing the game "kriegTTT_5x5_CHEAT" with 2 probes is 43.00% for 100 games
# The win/draw rate for the agent "OPHYPERB" playing the game "kriegTTT_5x5_CHEAT" with 2half probes is 38.00% for 100 games
# The win/draw rate for the agent "OPHYPERB" playing the game "kriegTTT_5x5_CHEAT" with 3 probes is 42.00% for 100 games

# %% [markdown]
# It is now worth looking into how performance degrades with fewer probes.
#
# First I will consider the number of games that can be completed without error compared to the number of probes.

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2], label='state_update')
ax1.set_title('Number of Games Completed')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Games Completed')
ax1.set_yscale('linear')
ax1.set_ylim([0,101])
ax1.bar(numNames, count_games_completed, color=u'#ff7f0e')
plt.show()

# %% [markdown]
# I will now consider whether the number of games won

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Proportion of Games Won that were Completed')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Games Won')
ax1.set_yscale('linear')
ax1.set_yticks(np.linspace(0, 100, 21))
ax1.set_ylim([0,100])
nobias_line, = ax1.plot(numNames, np.divide(total_score_ophyper,count_games_completed), marker='o', color=u'#ff7f0e')
plt.show()

# %% [markdown]
# Compared to ahyperlt

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Overall Score Against Power of Likelihood')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Overall Score')
ax1.set_yscale('linear')
ax1.set_yticks(np.linspace(0, 100, 21))
ax1.set_ylim([0,100])
ahyper8x8_win_rate = np.divide(total_score_ahyper[2],count_games_completed)
ahyper_line, = ax1.plot(ahyper8x8_win_rate)
ophyper_line, = ax1.plot(numNames, np.divide(total_score_ophyper,count_games_completed), marker='o')
ax1.legend((ophyper_line, ahyper_line), ('Opponent Modelling', 'Original Hyperplay'))
plt.show()

# %% [markdown]
# ### Move Results
#
# Calculating the average move time per game.
# This is expected to grow with the depth of the game and is expected to be different for the state update and the move selection.

# %%
class Tracker:
    '''
    Tracker tracks the average time for each move of each game played
    '''
    def __init__(self):
        self.time_sum = 0
        self.num_moves = 0
        self.times = list()
    
    def __str__(self):
        return "time_sum: " + str(self.time_sum) + " ms\n\tnum_moves: " + str(self.num_moves) + "\n\tmean_time: " + str(statistics.mean(self.times)) + "\n\tmedian_time: " + str(statistics.median(self.times)) + " ms\n\ttimes (ms): " + str(self.times)
    
    def addMove(self, num):
        self.time_sum += num
        self.num_moves+=1
        self.times.append(num)
    
    def getMeanTime(self):
        return statistics.mean(self.times)
    
    def getMedianTime(self):
        return statistics.median(self.times)

# Add the results for each move of each game played to a list of trackers for the update and select move times for the chosen player
time_to_update_list = list()
time_to_select_move_list = list()
max_num_steps = [0] * len(numNames)
for idx, (move_list, game) in enumerate(zip(move_list_games, data)):
    temp_time_to_update_list = list()
    temp_time_to_select_move_list = list()
    player_name = game['role_1'][0].upper()
    for move_set in move_list:
        for index, move_row in move_set.iterrows():
            if move_row['role_name'] == player_name:
                if move_row['step'] > len(temp_time_to_update_list) - 1:
                    max_num_steps[idx] += 1
                    temp_time_to_update_list.append(Tracker())
                    temp_time_to_select_move_list.append(Tracker())
                temp_time_to_update_list[move_row['step']].addMove(move_row['time_to_update'])
                temp_time_to_select_move_list[move_row['step']].addMove(move_row['time_to_select_move'])
    time_to_update_list.append(temp_time_to_update_list)
    time_to_select_move_list.append(temp_time_to_select_move_list)

# Print the data
for game_num, (game_time_to_update_list, game_time_to_select_move_list) in enumerate(zip(time_to_update_list, time_to_select_move_list)):
    print(str(numNames[game_num]))
    for idx, (update_step, select_step) in enumerate(zip(game_time_to_update_list, game_time_to_select_move_list)):
        print('\tStep: ' + str(idx) + "\n")
        print('\tTime taken to update states:')
        print('\t' + str(update_step)  + "\n")
        print('\tTime taken to select move:')
        print('\t' + str(select_step)  + "\n\n\n")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-007226e4a269> in <module>
#      37                     temp_time_to_update_list.append(Tracker())
#      38                     temp_time_to_select_move_list.append(Tracker())
# ---> 39                 temp_time_to_update_list[move_row['step']].addMove(move_row['time_to_update'])
#      40                 temp_time_to_select_move_list[move_row['step']].addMove(move_row['time_to_select_move'])
#      41     time_to_update_list.append(temp_time_to_update_list)
#
# IndexError: list index out of range

# %% [markdown]
# Now I will graph the findings

# %%
# Add the data to an array
mean_state_update_times = list()
mean_move_select_times = list()
median_state_update_times = list()
median_move_select_times = list()
for game_num, (game_time_to_update_list, game_time_to_select_move_list) in enumerate(zip(time_to_update_list, time_to_select_move_list)):
    temp_mean_state_update_times = list()
    temp_mean_move_select_times = list()
    temp_median_state_update_times = list()
    temp_median_move_select_times = list()
    for update_step, select_step in zip(game_time_to_update_list, game_time_to_select_move_list):
        temp_mean_state_update_times.append(update_step.getMeanTime())
        temp_mean_move_select_times.append(select_step.getMeanTime())
        temp_median_state_update_times.append(update_step.getMedianTime())
        temp_median_move_select_times.append(select_step.getMedianTime())
    mean_state_update_times.append(temp_mean_state_update_times)
    mean_move_select_times.append(temp_mean_move_select_times)
    median_state_update_times.append(temp_median_state_update_times)
    median_move_select_times.append(temp_median_move_select_times)

# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.5, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,1.25,1,1], label='state_update_mean')
ax1.set_title('Mean Time Taken to Update State Against Step Number')
ax1.set_xlabel('Steps')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
for idx, game_mean_state_update_times in enumerate(mean_state_update_times):
    ax1.plot(game_mean_state_update_times, label=str(numNames[idx]))
ax1.legend()

# Draw mean graph for Move Select
ax2 = fig.add_axes([1.15,1.25,1,1], label='move_select_mean')
ax2.set_title('Mean Time Taken to Select Move Against Step Number')
ax2.set_xlabel('Steps')
ax2.set_ylabel('Time (ms)')
ax2.set_yscale('linear')
for idx, game_mean_move_select_times in enumerate(mean_move_select_times):
    ax2.plot(game_mean_move_select_times, label=str(numNames[idx]))
ax2.legend()

# Draw median graph for State Update
ax3 = fig.add_axes([0,0,1,1], label='state_update_median')
ax3.set_title('Median Time Taken to Update State Against Step Number')
ax3.set_xlabel('Steps')
ax3.set_ylabel('Time (ms)')
ax3.set_yscale('log')
for idx, game_median_state_update_times in enumerate(median_state_update_times):
    ax3.plot(game_median_state_update_times, label=str(numNames[idx]))
ax3.legend()

# Draw median graph for Move Select
ax4 = fig.add_axes([1.15,0,1,1], label='move_select_median')
ax4.set_title('Median Time Taken to Select Move Against Step Number')
ax4.set_xlabel('Steps')
ax4.set_ylabel('Time (ms)')
ax4.set_yscale('linear')
for idx, game_median_move_select_times in enumerate(median_move_select_times):
    ax4.plot(game_median_move_select_times, label=str(numNames[idx]))
ax4.legend()

plt.show()

# %%
sum_game_median_state_update_times = list()
for idx, game_median_state_update_times in enumerate(median_state_update_times):
    sum_game_median_state_update_times.append(sum(game_median_state_update_times)/len(game_median_state_update_times))
    
# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.15, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Median Time Taken to Update State')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
ax1.set_ylim([1,100000])
ax1.bar(numNames, sum_game_median_state_update_times)

plt.show()
    
# sum_game_mean_state_update_times

# %%
sum_game_median_move_select_times = list()
for idx, game_median_move_select_times in enumerate(median_move_select_times):
    sum_game_median_move_select_times.append(sum(game_median_move_select_times)/len(game_median_move_select_times))
    
# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.15, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Median Time Taken to Select Move')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
ax1.set_ylim([1,100000])
ax1.bar(numNames, sum_game_median_move_select_times)

plt.show()
    
# sum_game_mean_state_update_times

# %% [markdown]
# ## Hypergame Utilization
#
# I will now consider how useful increasing the cap of hypergames was

# %%
max_hypergames = [8, 8, 8, 8, 8, 8]

hypergame_utilization_sum = list()
hypergame_utilization_max = list()
hypergame_utilization_count = list()
hypergame_utilization = list()

fig = plt.figure()

for idx, move_list in enumerate(move_list_games):
    hypergame_utilization_sum.append([0] * max_num_steps[idx])
    hypergame_utilization_max.append([0] * max_num_steps[idx])
    hypergame_utilization_count.append([0] * max_num_steps[idx])
    hypergame_utilization.append([])

    # Count number of hypergames used on average at each step out of the maximum number
    for game in move_list:
        for index, row in game.iterrows():
            if(row['player_name'] == 'ophyper'):
                hypergame_utilization_sum[idx][row['step']] += row['count_hypergames']
                hypergame_utilization_count[idx][row['step']] += 1
                if(row['count_hypergames'] / max_hypergames[idx] > hypergame_utilization_max[idx][row['step']]):
                    hypergame_utilization_max[idx][row['step']] = row['count_hypergames'] / max_hypergames[idx]
    hypergame_utilization[idx] = [(utilSum / count) / max_hypergames[idx] for utilSum, count in zip(hypergame_utilization_sum[idx], hypergame_utilization_count[idx])]

    # display
    
    ax1 = fig.add_axes([0,-idx - idx*0.25,1,1])
    ax1.set_title('Average proportion of hypergame usage at each step for ' + str(numNames[idx]))
    ax1.set_xlabel('Step')
    ax1.set_ylabel('Hypergame usage out of max of ' + str(max_hypergames[idx]))
    ax1.set_yscale('linear')
    ax1.set_yticks(np.linspace(0,1,11))
    ax1.set_ylim([0,1])
    ax1.bar(range(0, len(hypergame_utilization[idx])), hypergame_utilization[idx])

    ax2 = fig.add_axes([1.25,-idx  - idx*0.25,1,1])
    ax2.set_title('Maximum hypergame usage at each step for ' + str(numNames[idx]))
    ax2.set_xlabel('Step')
    ax2.set_ylabel('Hypergame usage out of max of ' + str(max_hypergames[idx]))
    ax2.set_yscale('linear')
    ax2.set_yticks(np.linspace(0,1,11))
    ax2.set_ylim([0,1])
    ax2.bar(range(0, len(hypergame_utilization_max[idx])), hypergame_utilization_max[idx])

plt.show()

# %% [markdown]
# ### Steps taken to win

# %%
# Calculate the average number of steps taken to win for each hypergame
steps_to_win_list = list()
for idx, (move_list, game) in enumerate(zip(move_list_games, data)):
    game_steps_to_win_list = list()
    winning_games = game[((game['player_1_score'] == 100) & (game['player_2_score'] == 0)) | (len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)]))] 
    winning_games_list = winning_games['match_id'].tolist()
    for moves in move_list:
        if(moves['match_id'][0] in winning_games_list):
            move_length = len(moves['match_id'])
            game_steps_to_win_list.append(moves['step'][move_length - 1] + 1)
    steps_to_win_list.append(game_steps_to_win_list)

# Print steps to win
mean_steps_to_win = list()
median_steps_to_win = list()
for idx, game_steps_to_win in enumerate(steps_to_win_list):
    mean = statistics.mean(game_steps_to_win)
    median = statistics.median(game_steps_to_win)
    print(f'{numNames[idx]}')
    print(f'\tMean steps to win: {mean}')
    print(f'\tMedian steps to win: {median}')
    mean_steps_to_win.append(mean)
    median_steps_to_win.append(median)

# Graph steps to win
fig = plt.figure()
ax1 = fig.add_axes([0,0,1.75,1.5])
ax1.set_title('Mean Number of Steps Taken to Win')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Steps')
ax1.set_yscale('linear')
ax1.set_yticks(range(0,36,1))
ax1.set_ylim([0,36])
ax1.bar(numNames, mean_steps_to_win)

ax2 = fig.add_axes([0,-1.75,1.75,1.5])
ax2.set_title('Median Number of Steps Taken to Win')
ax2.set_xlabel('Agent')
ax2.set_ylabel('Steps')
ax2.set_yscale('linear')
ax2.set_yticks(range(0,36,1))
ax2.set_ylim([0,36])
ax2.bar(numNames, median_steps_to_win)

plt.show()
