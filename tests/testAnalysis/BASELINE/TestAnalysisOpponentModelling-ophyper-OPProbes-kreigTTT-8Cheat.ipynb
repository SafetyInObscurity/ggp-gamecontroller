# %% [markdown]
# # <center>OP Hyper Power</center>
#
# This file is an interactive notebook to analyze the data obtained from tests.<br>
# The purpose of this notebook is to define a baseline for a model which can be improved upon.
# The game blind_breakthrough will be used since this seems to be the game the original hyperplay model performed the best at.
#
# **Note: It could be a good idea to look into using a stronger cheat agent for a better comparison**
#
# ## Reading in the Data
#
# First the match data must be read in.
# I will be reading in data obtained for a series of games where a hyperplayer with increasing resources competed against a CHEAT player who had access to the true state and was allowed 16 simulations per move.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import statistics
np.random.seed(42)

# Read in the csv files
numNames = ['2OPProbes', '4OPProbes', '8OPProbes', '16OPProbes', '32OPProbes', '64OPProbes']
data = list()

for idx, name in enumerate(numNames):
    file_name = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ophyper_OPProbes_8Cheat/' + name + '/testOutput.csv'
    data.append(pd.DataFrame)
    data[idx] = pd.read_csv(file_name, header=0)

# Read in the csv files
numNamesAhyper = ['2x2', '4x4', '8x8', '16x16', '32x32']
data_ahyper = list()

for idx, name in enumerate(numNamesAhyper):
    file_name = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ahyperlt_resources/' + name + '/testOutput.csv'
    data_ahyper.append(pd.DataFrame)
    data_ahyper[idx] = pd.read_csv(file_name, header=0)
    
# Print the first 5 rows of the data
for game in data:
    display(game.head())
# Out:
#                                            match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1601345702004          10       6000  XPLAYER          8
# 1            2  1601346014287          10       6000  XPLAYER          6
# 2            2  1601346194174          10       6000  XPLAYER          5
# 3            2  1601346471988          10       6000  XPLAYER          7
# 4            2  1601346612458          10       6000  XPLAYER          4
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPER              50  oplayer    CHEAT              50
# 2  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 3  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 4  xplayer  OPHYPER             100  oplayer    CHEAT               0
#                                            match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1601345562310          10       6000  XPLAYER          5
# 1            2  1601345792448          10       6000  XPLAYER          5
# 2            2  1601346119765          10       6000  XPLAYER          5
# 3            2  1601346418371          10       6000  XPLAYER          6
# 4            2  1601346718593          10       6000  XPLAYER          7
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 2  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 3  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 4  xplayer  OPHYPER             100  oplayer    CHEAT               0
#                                            match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1601346060745          10       6000  XPLAYER         15
# 1            2  1601346287188          10       6000  XPLAYER          4
# 2            2  1601346944869          10       6000  XPLAYER          7
# 3            2  1601347317877          10       6000  XPLAYER          6
# 4            2  1601347513617          10       6000  XPLAYER          4
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 2  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPER             100  oplayer    CHEAT               0
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1601345884324          10       6000  XPLAYER          7
# 1            2  1601346485049          10       6000  XPLAYER          7
# 2            2  1601346756950          10       6000  XPLAYER          4
# 3            2  1601347162285          10       6000  XPLAYER          6
# 4            2  1601347549862          10       6000  XPLAYER          5
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPER              50  oplayer    CHEAT              50
# 2  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 3  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPER             100  oplayer    CHEAT               0
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1601347958165          10       6000  XPLAYER         12
# 1            2  1601348600898          10       6000  XPLAYER          5
# 2            2  1601349662491          10       6000  XPLAYER          5
# 3            2  1601351895542          10       6000  XPLAYER          7
# 4            2  1601352518160          10       6000  XPLAYER          5
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 2  xplayer  OPHYPER              50  oplayer    CHEAT              50
# 3  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPER               0  oplayer    CHEAT             100
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1601347800756          10       6000  XPLAYER          6
# 1            2  1601351553484          10       6000  XPLAYER          7
# 2            2  1601353921048          10       6000  XPLAYER          9
# 3            2  1601355381978          10       6000  XPLAYER          7
# 4            2  1601356111720          10       6000  XPLAYER          4
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPER              50  oplayer    CHEAT              50
# 2  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPER              50  oplayer    CHEAT              50
# 4  xplayer  OPHYPER             100  oplayer    CHEAT               0

# %% [markdown]
# Next, the move data should be read in for each match
#
# *Note: time_to_update and time_to_select_move are in milliseconds*

# %%
move_list_games = list()
for idx, name in enumerate(numNames):
    file_name_prefix = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ophyper_OPProbes_8Cheat/' + name + '/moveset/'
    temp_move_list = list()
    for match_name in data[idx]['match_id']:
        file_name = file_name_prefix + match_name + '.csv'
        temp_move_list.append(pd.read_csv(file_name, names=['match_id','game_name','step','role_name','player_name','count_hypergames','num_probes','time_to_update','time_to_select_move','move_chosen','last_move_illegal','numTimesMovesSimulated','numTimesHypergameForward']))
    move_list_games.append(temp_move_list)

move_list_games_ahyper = list()
for idx, name in enumerate(numNamesAhyper):
    file_name_prefix = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ahyperlt_resources/' + name + '/moveset/'
    temp_move_list = list()
    for match_name in data_ahyper[idx]['match_id']:
        file_name = file_name_prefix + match_name + '.csv'
        temp_move_list.append(pd.read_csv(file_name, names=['match_id','game_name','step','role_name','player_name','count_hypergames','num_probes','time_to_update','time_to_select_move','move_chosen','last_move_illegal','numTimesMovesSimulated','numTimesHypergameForward']))
    move_list_games_ahyper.append(temp_move_list)
    
# Verify by printing the head of the first game
for move_list in move_list_games:
    display(move_list[0])
# Out:
#                                             match_id           game_name  \
# 0   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 1   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 2   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 3   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 4   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 5   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 6   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 7   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 8   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 9   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 10  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 11  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 12  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 13  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 14  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
# 15  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_2OPProbes_0  kriegTTT_5x5_CHEAT
#
#     step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0      0   OPLAYER       cheat                 1           8              19
# 1      0   XPLAYER     ophyper                 1           8              19
# 2      1   OPLAYER       cheat                 1           8              76
# 3      1   XPLAYER     ophyper                 8           8            3378
# 4      2   OPLAYER       cheat                 1           8               5
# 5      2   XPLAYER     ophyper                 8           8           14359
# 6      3   OPLAYER       cheat                 1           8               5
# 7      3   XPLAYER     ophyper                 8           8           39257
# 8      4   OPLAYER       cheat                 1           8              16
# 9      4   XPLAYER     ophyper                 8           8           11804
# 10     5   OPLAYER       cheat                 1           8              22
# 11     5   XPLAYER     ophyper                 8           8           30541
# 12     6   OPLAYER       cheat                 1           8              38
# 13     6   XPLAYER     ophyper                 8           8           24892
# 14     7   OPLAYER       cheat                 1           8               7
# 15     7   XPLAYER     ophyper                 8           8           31249
#
#     time_to_select_move  move_chosen  last_move_illegal  \
# 0                 12091  (MARK 4 1 )              False
# 1                 12828  (MARK 3 2 )              False
# 2                  9527  (MARK 3 5 )              False
# 3                 41755  (MARK 2 4 )              False
# 4                  8829  (MARK 3 4 )              False
# 5                 34351  (MARK 5 5 )              False
# 6                  7904  (MARK 1 3 )              False
# 7                 31112  (MARK 4 4 )              False
# 8                  7608  (MARK 4 2 )              False
# 9                 23720  (MARK 3 3 )              False
# 10                 7139  (MARK 1 4 )              False
# 11                19714  (MARK 1 1 )              False
# 12                 6390  (MARK 1 5 )              False
# 13                16798  (MARK 3 1 )              False
# 14                 4563  (MARK 1 2 )              False
# 15                15265  (MARK 3 4 )              False
#
#     numTimesMovesSimulated  numTimesHypergameForward
# 0                      175                         0
# 1                      200                         0
# 2                      168                        16
# 3                     1586                         8
# 4                      161                         1
# 5                     1856                         8
# 6                      154                         2
# 7                     2834                       587
# 8                      147                         6
# 9                     1696                         8
# 10                     140                        10
# 11                    2636                       496
# 12                     133                        17
# 13                    2522                       455
# 14                     126                         4
# 15                    3376                       927
#                                            match_id           game_name  step  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_0  kriegTTT_5x5_CHEAT     0
# 1  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_0  kriegTTT_5x5_CHEAT     0
# 2  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_0  kriegTTT_5x5_CHEAT     1
# 3  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_0  kriegTTT_5x5_CHEAT     1
# 4  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_0  kriegTTT_5x5_CHEAT     2
# 5  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_0  kriegTTT_5x5_CHEAT     2
# 6  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_0  kriegTTT_5x5_CHEAT     3
# 7  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_0  kriegTTT_5x5_CHEAT     3
# 8  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_0  kriegTTT_5x5_CHEAT     4
# 9  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_4OPProbes_0  kriegTTT_5x5_CHEAT     4
#
#   role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0   OPLAYER       cheat                 1           8              18
# 1   XPLAYER     ophyper                 1           8              18
# 2   OPLAYER       cheat                 1           8              87
# 3   XPLAYER     ophyper                 8           8            6644
# 4   OPLAYER       cheat                 1           8              48
# 5   XPLAYER     ophyper                 8           8           25059
# 6   OPLAYER       cheat                 1           8               8
# 7   XPLAYER     ophyper                 8           8           22139
# 8   OPLAYER       cheat                 1           8              85
# 9   XPLAYER     ophyper                 8           8           20411
#
#    time_to_select_move  move_chosen  last_move_illegal  \
# 0                12520  (MARK 3 2 )              False
# 1                13242  (MARK 5 5 )              False
# 2                10922  (MARK 1 3 )              False
# 3                42138  (MARK 4 2 )              False
# 4                 9618  (MARK 3 4 )              False
# 5                35568  (MARK 2 1 )              False
# 6                 7472  (MARK 3 3 )              False
# 7                32785  (MARK 2 2 )              False
# 8                 4020  (MARK 3 1 )              False
# 9                26275  (MARK 5 2 )              False
#
#    numTimesMovesSimulated  numTimesHypergameForward
# 0                     175                         0
# 1                     200                         0
# 2                     168                        17
# 3                    1636                         9
# 4                     161                        17
# 5                    2240                         8
# 6                     154                         2
# 7                    2144                         8
# 8                     147                        22
# 9                    2140                        32
#                                             match_id           game_name  \
# 0   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 1   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 2   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 3   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 4   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 5   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 6   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 7   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 8   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 9   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 10  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 11  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 12  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 13  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 14  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 15  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 16  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 17  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 18  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 19  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 20  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 21  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 22  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 23  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 24  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 25  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 26  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 27  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 28  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
# 29  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_8OPProbes_0  kriegTTT_5x5_CHEAT
#
#     step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0      0   OPLAYER       cheat                 1           8              16
# 1      0   XPLAYER     ophyper                 1           8              22
# 2      1   OPLAYER       cheat                 1           8              95
# 3      1   XPLAYER     ophyper                 8           8           11678
# 4      2   OPLAYER       cheat                 1           8              39
# 5      2   XPLAYER     ophyper                 8           8           44772
# 6      3   OPLAYER       cheat                 1           8              24
# 7      3   XPLAYER     ophyper                 8           8           35704
# 8      4   OPLAYER       cheat                 1           8              52
# 9      4   XPLAYER     ophyper                 8           8           25314
# 10     5   OPLAYER       cheat                 1           8               7
# 11     5   XPLAYER     ophyper                 8           8           23421
# 12     6   OPLAYER       cheat                 1           8              10
# 13     6   XPLAYER     ophyper                 8           8           23440
# 14     7   OPLAYER       cheat                 1           8              55
# 15     7   XPLAYER     ophyper                 8           8           23093
# 16     8   OPLAYER       cheat                 1           8               8
# 17     8   XPLAYER     ophyper                 8           8           17946
# 18     9   OPLAYER       cheat                 1           8              17
# 19     9   XPLAYER     ophyper                 8           8           17065
# 20    10   OPLAYER       cheat                 1           8              23
# 21    10   XPLAYER     ophyper                 8           8           16255
# 22    11   OPLAYER       cheat                 1           8              19
# 23    11   XPLAYER     ophyper                 8           8          149112
# 24    12   OPLAYER       cheat                 1           8              40
# 25    12   XPLAYER     ophyper                 8           8           14959
# 26    13   OPLAYER       cheat                 1           8              18
# 27    13   XPLAYER     ophyper                 8           8           14822
# 28    14   OPLAYER       cheat                 1           8              40
# 29    14   XPLAYER     ophyper                 8           8           13963
#
#     time_to_select_move  move_chosen  last_move_illegal  \
# 0                 13535  (MARK 1 5 )              False
# 1                 14027  (MARK 4 4 )              False
# 2                 10344  (MARK 1 4 )              False
# 3                 40169  (MARK 3 4 )              False
# 4                  8587  (MARK 2 2 )              False
# 5                 31671  (MARK 2 4 )              False
# 6                  6571  (MARK 5 4 )              False
# 7                 20640  (MARK 1 4 )              False
# 8                  7908  (MARK 3 1 )              False
# 9                 19377  (MARK 5 4 )              False
# 10                 6948  (MARK 3 5 )              False
# 11                19508  (MARK 3 2 )              False
# 12                 5753  (MARK 1 2 )              False
# 13                16416  (MARK 1 4 )              False
# 14                 4412  (MARK 2 1 )              False
# 15                15590  (MARK 5 4 )              False
# 16                 3724  (MARK 4 5 )              False
# 17                15126  (MARK 3 1 )              False
# 18                 2973  (MARK 4 4 )              False
# 19                14074  (MARK 2 1 )              False
# 20                 2687  (MARK 5 2 )              False
# 21                12405  (MARK 1 3 )              False
# 22                 2537  (MARK 5 5 )              False
# 23                13512  (MARK 5 4 )              False
# 24                 1776  (MARK 4 4 )              False
# 25                14121  (MARK 1 4 )              False
# 26                 2084  (MARK 3 4 )              False
# 27                13701  (MARK 3 5 )              False
# 28                 1810  (MARK 2 5 )              False
# 29                11703  (MARK 3 1 )              False
#
#     numTimesMovesSimulated  numTimesHypergameForward
# 0                      175                         0
# 1                      200                         0
# 2                      168                        19
# 3                     1736                         8
# 4                      161                        12
# 5                     3008                         9
# 6                      154                         8
# 7                     2880                         8
# 8                      147                        20
# 9                     2760                        65
# 10                     140                         1
# 11                    2632                        76
# 12                     133                         1
# 13                    2632                         9
# 14                     126                        19
# 15                    2928                       126
# 16                     119                         2
# 17                    2496                        90
# 18                     112                         8
# 19                    2376                        65
# 20                     105                         9
# 21                    2280                        53
# 22                     105                         6
# 23                   11744                       620
# 24                      98                        20
# 25                    2456                        70
# 26                      91                         9
# 27                    2328                        50
# 28                      84                        18
# 29                    2200                        34
#                                              match_id           game_name  \
# 0   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 1   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 2   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 3   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 4   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 5   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 6   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 7   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 8   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 9   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 10  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 11  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 12  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
# 13  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_16OPProbes_0  kriegTTT_5x5_CHEAT
#
#     step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0      0   OPLAYER       cheat                 1           8              26
# 1      0   XPLAYER     ophyper                 1           8               5
# 2      1   OPLAYER       cheat                 1           8              54
# 3      1   XPLAYER     ophyper                 8           8           17315
# 4      2   OPLAYER       cheat                 1           8              15
# 5      2   XPLAYER     ophyper                 8           8           83131
# 6      3   OPLAYER       cheat                 1           8              36
# 7      3   XPLAYER     ophyper                 8           8           77275
# 8      4   OPLAYER       cheat                 1           8              15
# 9      4   XPLAYER     ophyper                 8           8           55680
# 10     5   OPLAYER       cheat                 1           8              14
# 11     5   XPLAYER     ophyper                 8           8           55840
# 12     6   OPLAYER       cheat                 1           8              36
# 13     6   XPLAYER     ophyper                 8           8           79144
#
#     time_to_select_move  move_chosen  last_move_illegal  \
# 0                 12790  (MARK 3 1 )              False
# 1                 13764  (MARK 3 4 )              False
# 2                 10446  (MARK 2 4 )              False
# 3                 39870  (MARK 4 4 )              False
# 4                  9862  (MARK 4 3 )              False
# 5                 32233  (MARK 5 4 )              False
# 6                  8883  (MARK 2 2 )              False
# 7                 25701  (MARK 2 4 )              False
# 8                  7061  (MARK 3 3 )              False
# 9                 24466  (MARK 3 3 )              False
# 10                 6802  (MARK 2 3 )              False
# 11                23082  (MARK 5 2 )              False
# 12                 3362  (MARK 2 1 )              False
# 13                20574  (MARK 2 4 )              False
#
#     numTimesMovesSimulated  numTimesHypergameForward
# 0                      175                         0
# 1                      200                         0
# 2                      168                         6
# 3                     1936                         8
# 4                      161                         1
# 5                     4544                         8
# 6                      154                         9
# 7                     4720                        34
# 8                      147                         5
# 9                     4192                        70
# 10                     140                         5
# 11                    4000                        67
# 12                     140                        12
# 13                    5328                        50
#                                              match_id           game_name  \
# 0   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 1   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 2   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 3   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 4   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 5   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 6   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 7   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 8   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 9   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 10  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 11  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 12  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 13  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 14  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 15  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 16  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 17  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 18  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 19  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 20  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 21  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 22  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
# 23  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_32OPProbes_0  kriegTTT_5x5_CHEAT
#
#     step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0      0   OPLAYER       cheat                 1           8              13
# 1      0   XPLAYER     ophyper                 1           8              12
# 2      1   OPLAYER       cheat                 1           8              93
# 3      1   XPLAYER     ophyper                 8           8           27439
# 4      2   OPLAYER       cheat                 1           8              23
# 5      2   XPLAYER     ophyper                 8           8          159808
# 6      3   OPLAYER       cheat                 1           8              37
# 7      3   XPLAYER     ophyper                 8           8          138357
# 8      4   OPLAYER       cheat                 1           8              11
# 9      4   XPLAYER     ophyper                 8           8          119341
# 10     5   OPLAYER       cheat                 1           8              32
# 11     5   XPLAYER     ophyper                 8           8          433657
# 12     6   OPLAYER       cheat                 1           8              29
# 13     6   XPLAYER     ophyper                 8           8           67787
# 14     7   OPLAYER       cheat                 1           8              16
# 15     7   XPLAYER     ophyper                 8           8          555567
# 16     8   OPLAYER       cheat                 1           8              39
# 17     8   XPLAYER     ophyper                 8           8           65263
# 18     9   OPLAYER       cheat                 1           8               9
# 19     9   XPLAYER     ophyper                 8           8           54262
# 20    10   OPLAYER       cheat                 1           8              23
# 21    10   XPLAYER     ophyper                 8           8           49980
# 22    11   OPLAYER       cheat                 1           8              25
# 23    11   XPLAYER     ophyper                 5           8          723129
#
#     time_to_select_move  move_chosen  last_move_illegal  \
# 0                 12555  (MARK 3 3 )              False
# 1                 13402  (MARK 4 1 )              False
# 2                 10113  (MARK 3 1 )              False
# 3                 38926  (MARK 3 4 )              False
# 4                  9458  (MARK 1 4 )              False
# 5                 33370  (MARK 1 1 )              False
# 6                  9110  (MARK 4 5 )              False
# 7                 28802  (MARK 4 4 )              False
# 8                  7635  (MARK 4 4 )              False
# 9                 23134  (MARK 2 1 )              False
# 10                 6547  (MARK 2 4 )              False
# 11                15315  (MARK 3 1 )              False
# 12                 6436  (MARK 1 1 )              False
# 13                14654  (MARK 1 2 )              False
# 14                 6613  (MARK 5 3 )              False
# 15                12732  (MARK 3 1 )              False
# 16                 5682  (MARK 2 2 )              False
# 17                12963  (MARK 4 3 )              False
# 18                 4078  (MARK 5 1 )              False
# 19                10737  (MARK 3 1 )              False
# 20                 3537  (MARK 2 3 )              False
# 21                10602  (MARK 5 4 )              False
# 22                 3186  (MARK 2 5 )              False
# 23                 4744  (MARK 3 1 )              False
#
#     numTimesMovesSimulated  numTimesHypergameForward
# 0                      175                         0
# 1                      200                         0
# 2                      168                        20
# 3                     2336                         8
# 4                      161                         3
# 5                     7616                         9
# 6                      154                        12
# 7                     7296                         8
# 8                      147                         4
# 9                     6976                        10
# 10                     140                        16
# 11                   22880                       519
# 12                     140                        13
# 13                    6432                        90
# 14                     133                         5
# 15                   28000                       630
# 16                     133                        16
# 17                    7264                        93
# 18                     126                         2
# 19                    5792                         8
# 20                     119                         8
# 21                    6880                        89
# 22                     112                         8
# 23                   44840                      1319
#                                              match_id           game_name  \
# 0   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 1   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 2   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 3   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 4   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 5   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 6   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 7   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 8   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 9   kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 10  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
# 11  kriegTTT_5x5_CHEAT_8x8ophyper_8cheat_64OPProbes_0  kriegTTT_5x5_CHEAT
#
#     step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0      0   OPLAYER       cheat                 1           8              13
# 1      0   XPLAYER     ophyper                 1           8              13
# 2      1   OPLAYER       cheat                 1           8              88
# 3      1   XPLAYER     ophyper                 8           8           49786
# 4      2   OPLAYER       cheat                 1           8              40
# 5      2   XPLAYER     ophyper                 8           8          311665
# 6      3   OPLAYER       cheat                 1           8               7
# 7      3   XPLAYER     ophyper                 7           8         1002882
# 8      4   OPLAYER       cheat                 1           8              15
# 9      4   XPLAYER     ophyper                 8           8          300484
# 10     5   OPLAYER       cheat                 1           8              36
# 11     5   XPLAYER     ophyper                 7           8          644575
#
#     time_to_select_move  move_chosen  last_move_illegal  \
# 0                 12387  (MARK 4 5 )              False
# 1                 13171  (MARK 5 2 )              False
# 2                  9938  (MARK 1 2 )              False
# 3                 37799  (MARK 4 2 )              False
# 4                  8247  (MARK 1 4 )              False
# 5                 32636  (MARK 4 1 )              False
# 6                  7008  (MARK 3 1 )              False
# 7                 23750  (MARK 2 5 )              False
# 8                  6616  (MARK 1 3 )              False
# 9                 22483  (MARK 5 4 )              False
# 10                 3564  (MARK 1 5 )              False
# 11                15507  (MARK 5 5 )              False
#
#     numTimesMovesSimulated  numTimesHypergameForward
# 0                      175                         0
# 1                      200                         0
# 2                      168                        15
# 3                     3136                         9
# 4                      161                         7
# 5                    13760                         8
# 6                      154                         2
# 7                    45392                       583
# 8                      147                         5
# 9                    15680                        11
# 10                     140                        14
# 11                   38816                       493

# %% [markdown]
# ## Analysis of Data
#
# ### Overall Agent Results
#
# The average score of the agent will be calculated across all games

# %%
count_games_completed = list()
total_score_ophyper = list()
for idx, game in enumerate(data):
    total_score = data[idx]['player_1_score'][data[idx]['player_1_score'] >= 50].count() * 100
    total_count = len(data[idx]['player_1_score'])
    count_games_completed.append(total_count)
    total_score_ophyper.append(total_score)
    print(f"The win/draw rate for the agent \"" + str(data[idx]['player_1'][0]) + "\" playing the game \"" + str(data[idx]['game_name'][0]) + "\" with " + str(numNames[idx]) + f" probes is {(total_score/total_count):.2f}% for " + str(total_count) + " games")

# calc results for ahyper
win_count_ahyper = list()
total_score_ahyper = list()
for idx, game in enumerate(data_ahyper):
    total_score = data_ahyper[idx]['player_1_score'][data_ahyper[idx]['player_1_score'] >= 50].count() * 100
    total_score_ahyper.append(total_score)
    game_count = [len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 0)]), len(game[(game['player_1_score'] == 0) & (game['player_2_score'] == 100)]), len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)])]
    win_count_ahyper.append(game_count[0])
    
# Display a pie chart
fig = plt.figure()
data_len = len(data)
win_count = list()
for idx, game in enumerate(data):
    ax = fig.add_axes([(data_len - idx)%2,math.ceil((data_len - idx)/2),1,1])
    ax.axis('equal')
    ax.set_title('Win rate for ' + str(numNames[idx]))
    result = ['Won', 'Lost', 'Drew']
    game_count = [len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 0)]), len(game[(game['player_1_score'] == 0) & (game['player_2_score'] == 100)]), len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)])]
    win_count.append(game_count[0])
    ax.pie(game_count, labels = result,autopct='%1.1f%%')
plt.show()
# Out:
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 2OPProbes probes is 59.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 4OPProbes probes is 53.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 8OPProbes probes is 44.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 16OPProbes probes is 57.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 32OPProbes probes is 50.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 64OPProbes probes is 55.00% for 100 games

# %% [markdown]
# It is now worth looking into how performance degrades with fewer probes.
#
# First I will consider the number of games that can be completed without error compared to the number of probes.

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2], label='state_update')
ax1.set_title('Number of Games Completed')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Games Completed')
ax1.set_yscale('linear')
ax1.set_ylim([0,101])
ax1.bar(numNames, count_games_completed, color=u'#ff7f0e')
plt.show()

# %% [markdown]
# I will now consider whether the number of games won

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Proportion of Games Won that were Completed')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Games Won')
ax1.set_yscale('linear')
ax1.set_yticks(np.linspace(0, 100, 21))
ax1.set_ylim([0,100])
nobias_line, = ax1.plot(numNames, np.divide(total_score_ophyper,count_games_completed), marker='o', color=u'#ff7f0e')
plt.show()

# %% [markdown]
# Compared to ahyperlt

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Overall Score Against Power of Likelihood')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Overall Score')
ax1.set_yscale('linear')
ax1.set_yticks(np.linspace(0, 100, 21))
ax1.set_ylim([0,100])
ahyper8x8_win_rate = np.divide(total_score_ahyper[2],count_games_completed)
ahyper_line, = ax1.plot(ahyper8x8_win_rate)
ophyper_line, = ax1.plot(numNames, np.divide(total_score_ophyper,count_games_completed), marker='o')
ax1.legend((ophyper_line, ahyper_line), ('Opponent Modelling', 'Original Hyperplay'))
plt.show()

# %% [markdown]
# ### Move Results
#
# Calculating the average move time per game.
# This is expected to grow with the depth of the game and is expected to be different for the state update and the move selection.

# %%
class Tracker:
    '''
    Tracker tracks the average time for each move of each game played
    '''
    def __init__(self):
        self.time_sum = 0
        self.num_moves = 0
        self.times = list()
    
    def __str__(self):
        return "time_sum: " + str(self.time_sum) + " ms\n\tnum_moves: " + str(self.num_moves) + "\n\tmean_time: " + str(statistics.mean(self.times)) + "\n\tmedian_time: " + str(statistics.median(self.times)) + " ms\n\ttimes (ms): " + str(self.times)
    
    def addMove(self, num):
        self.time_sum += num
        self.num_moves+=1
        self.times.append(num)
    
    def getMeanTime(self):
        return statistics.mean(self.times)
    
    def getMedianTime(self):
        return statistics.median(self.times)

# Add the results for each move of each game played to a list of trackers for the update and select move times for the chosen player
time_to_update_list = list()
time_to_select_move_list = list()
max_num_steps = [0] * len(numNames)
for idx, (move_list, game) in enumerate(zip(move_list_games, data)):
    temp_time_to_update_list = list()
    temp_time_to_select_move_list = list()
    player_name = game['role_1'][0].upper()
    for move_set in move_list:
        for index, move_row in move_set.iterrows():
            if move_row['role_name'] == player_name:
                if move_row['step'] > len(temp_time_to_update_list) - 1:
                    max_num_steps[idx] += 1
                    temp_time_to_update_list.append(Tracker())
                    temp_time_to_select_move_list.append(Tracker())
                temp_time_to_update_list[move_row['step']].addMove(move_row['time_to_update'])
                temp_time_to_select_move_list[move_row['step']].addMove(move_row['time_to_select_move'])
    time_to_update_list.append(temp_time_to_update_list)
    time_to_select_move_list.append(temp_time_to_select_move_list)

# Print the data
for game_num, (game_time_to_update_list, game_time_to_select_move_list) in enumerate(zip(time_to_update_list, time_to_select_move_list)):
    print(str(numNames[game_num]))
    for idx, (update_step, select_step) in enumerate(zip(game_time_to_update_list, game_time_to_select_move_list)):
        print('\tStep: ' + str(idx) + "\n")
        print('\tTime taken to update states:')
        print('\t' + str(update_step)  + "\n")
        print('\tTime taken to select move:')
        print('\t' + str(select_step)  + "\n\n\n")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-007226e4a269> in <module>
#      37                     temp_time_to_update_list.append(Tracker())
#      38                     temp_time_to_select_move_list.append(Tracker())
# ---> 39                 temp_time_to_update_list[move_row['step']].addMove(move_row['time_to_update'])
#      40                 temp_time_to_select_move_list[move_row['step']].addMove(move_row['time_to_select_move'])
#      41     time_to_update_list.append(temp_time_to_update_list)
#
# IndexError: list index out of range

# %% [markdown]
# Now I will graph the findings

# %%
# Add the data to an array
mean_state_update_times = list()
mean_move_select_times = list()
median_state_update_times = list()
median_move_select_times = list()
for game_num, (game_time_to_update_list, game_time_to_select_move_list) in enumerate(zip(time_to_update_list, time_to_select_move_list)):
    temp_mean_state_update_times = list()
    temp_mean_move_select_times = list()
    temp_median_state_update_times = list()
    temp_median_move_select_times = list()
    for update_step, select_step in zip(game_time_to_update_list, game_time_to_select_move_list):
        temp_mean_state_update_times.append(update_step.getMeanTime())
        temp_mean_move_select_times.append(select_step.getMeanTime())
        temp_median_state_update_times.append(update_step.getMedianTime())
        temp_median_move_select_times.append(select_step.getMedianTime())
    mean_state_update_times.append(temp_mean_state_update_times)
    mean_move_select_times.append(temp_mean_move_select_times)
    median_state_update_times.append(temp_median_state_update_times)
    median_move_select_times.append(temp_median_move_select_times)

# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.5, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,1.25,1,1], label='state_update_mean')
ax1.set_title('Mean Time Taken to Update State Against Step Number')
ax1.set_xlabel('Steps')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
for idx, game_mean_state_update_times in enumerate(mean_state_update_times):
    ax1.plot(game_mean_state_update_times, label=str(numNames[idx]))
ax1.legend()

# Draw mean graph for Move Select
ax2 = fig.add_axes([1.15,1.25,1,1], label='move_select_mean')
ax2.set_title('Mean Time Taken to Select Move Against Step Number')
ax2.set_xlabel('Steps')
ax2.set_ylabel('Time (ms)')
ax2.set_yscale('linear')
for idx, game_mean_move_select_times in enumerate(mean_move_select_times):
    ax2.plot(game_mean_move_select_times, label=str(numNames[idx]))
ax2.legend()

# Draw median graph for State Update
ax3 = fig.add_axes([0,0,1,1], label='state_update_median')
ax3.set_title('Median Time Taken to Update State Against Step Number')
ax3.set_xlabel('Steps')
ax3.set_ylabel('Time (ms)')
ax3.set_yscale('log')
for idx, game_median_state_update_times in enumerate(median_state_update_times):
    ax3.plot(game_median_state_update_times, label=str(numNames[idx]))
ax3.legend()

# Draw median graph for Move Select
ax4 = fig.add_axes([1.15,0,1,1], label='move_select_median')
ax4.set_title('Median Time Taken to Select Move Against Step Number')
ax4.set_xlabel('Steps')
ax4.set_ylabel('Time (ms)')
ax4.set_yscale('linear')
for idx, game_median_move_select_times in enumerate(median_move_select_times):
    ax4.plot(game_median_move_select_times, label=str(numNames[idx]))
ax4.legend()

plt.show()

# %%
sum_game_median_state_update_times = list()
for idx, game_median_state_update_times in enumerate(median_state_update_times):
    sum_game_median_state_update_times.append(sum(game_median_state_update_times)/len(game_median_state_update_times))
    
# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.15, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Median Time Taken to Update State')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
ax1.set_ylim([1,100000])
ax1.bar(numNames, sum_game_median_state_update_times)

plt.show()
    
# sum_game_mean_state_update_times

# %%
sum_game_median_move_select_times = list()
for idx, game_median_move_select_times in enumerate(median_move_select_times):
    sum_game_median_move_select_times.append(sum(game_median_move_select_times)/len(game_median_move_select_times))
    
# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.15, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Median Time Taken to Select Move')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
ax1.set_ylim([1,100000])
ax1.bar(numNames, sum_game_median_move_select_times)

plt.show()
    
# sum_game_mean_state_update_times
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-577fa770001c> in <module>
#       1 sum_game_median_move_select_times = list()
# ----> 2 for idx, game_median_move_select_times in enumerate(median_move_select_times):
#       3     sum_game_median_move_select_times.append(sum(game_median_move_select_times)/len(game_median_move_select_times))
#       4
#       5 # Put into graphs
#
# NameError: name 'median_move_select_times' is not defined

# %% [markdown]
# ## Hypergame Utilization
#
# I will now consider how useful increasing the cap of hypergames was

# %%
max_hypergames = [8, 8, 8, 8, 8, 8]

hypergame_utilization_sum = list()
hypergame_utilization_max = list()
hypergame_utilization_count = list()
hypergame_utilization = list()

fig = plt.figure()

for idx, move_list in enumerate(move_list_games):
    hypergame_utilization_sum.append([0] * max_num_steps[idx])
    hypergame_utilization_max.append([0] * max_num_steps[idx])
    hypergame_utilization_count.append([0] * max_num_steps[idx])
    hypergame_utilization.append([])

    # Count number of hypergames used on average at each step out of the maximum number
    for game in move_list:
        for index, row in game.iterrows():
            if(row['player_name'] == 'ophyper'):
                hypergame_utilization_sum[idx][row['step']] += row['count_hypergames']
                hypergame_utilization_count[idx][row['step']] += 1
                if(row['count_hypergames'] / max_hypergames[idx] > hypergame_utilization_max[idx][row['step']]):
                    hypergame_utilization_max[idx][row['step']] = row['count_hypergames'] / max_hypergames[idx]
    hypergame_utilization[idx] = [(utilSum / count) / max_hypergames[idx] for utilSum, count in zip(hypergame_utilization_sum[idx], hypergame_utilization_count[idx])]

    # display
    
    ax1 = fig.add_axes([0,-idx - idx*0.25,1,1])
    ax1.set_title('Average proportion of hypergame usage at each step for ' + str(numNames[idx]))
    ax1.set_xlabel('Step')
    ax1.set_ylabel('Hypergame usage out of max of ' + str(max_hypergames[idx]))
    ax1.set_yscale('linear')
    ax1.set_yticks(np.linspace(0,1,11))
    ax1.set_ylim([0,1])
    ax1.bar(range(0, len(hypergame_utilization[idx])), hypergame_utilization[idx])

    ax2 = fig.add_axes([1.25,-idx  - idx*0.25,1,1])
    ax2.set_title('Maximum hypergame usage at each step for ' + str(numNames[idx]))
    ax2.set_xlabel('Step')
    ax2.set_ylabel('Hypergame usage out of max of ' + str(max_hypergames[idx]))
    ax2.set_yscale('linear')
    ax2.set_yticks(np.linspace(0,1,11))
    ax2.set_ylim([0,1])
    ax2.bar(range(0, len(hypergame_utilization_max[idx])), hypergame_utilization_max[idx])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-69ec6bda5b08> in <module>
#      18         for index, row in game.iterrows():
#      19             if(row['player_name'] == 'ophyper'):
# ---> 20                 hypergame_utilization_sum[idx][row['step']] += row['count_hypergames']
#      21                 hypergame_utilization_count[idx][row['step']] += 1
#      22                 if(row['count_hypergames'] / max_hypergames[idx] > hypergame_utilization_max[idx][row['step']]):
#
# IndexError: list index out of range

# %% [markdown]
# ### Steps taken to win

# %%
# Calculate the average number of steps taken to win for each hypergame
steps_to_win_list = list()
for idx, (move_list, game) in enumerate(zip(move_list_games, data)):
    game_steps_to_win_list = list()
    winning_games = game[((game['player_1_score'] == 100) & (game['player_2_score'] == 0)) | (len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)]))] 
    winning_games_list = winning_games['match_id'].tolist()
    for moves in move_list:
        if(moves['match_id'][0] in winning_games_list):
            move_length = len(moves['match_id'])
            game_steps_to_win_list.append(moves['step'][move_length - 1] + 1)
    steps_to_win_list.append(game_steps_to_win_list)

# Print steps to win
mean_steps_to_win = list()
median_steps_to_win = list()
for idx, game_steps_to_win in enumerate(steps_to_win_list):
    mean = statistics.mean(game_steps_to_win)
    median = statistics.median(game_steps_to_win)
    print(f'{numNames[idx]}')
    print(f'\tMean steps to win: {mean}')
    print(f'\tMedian steps to win: {median}')
    mean_steps_to_win.append(mean)
    median_steps_to_win.append(median)

# Graph steps to win
fig = plt.figure()
ax1 = fig.add_axes([0,0,1.75,1.5])
ax1.set_title('Mean Number of Steps Taken to Win')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Steps')
ax1.set_yscale('linear')
ax1.set_yticks(range(0,36,1))
ax1.set_ylim([0,36])
ax1.bar(numNames, mean_steps_to_win)

ax2 = fig.add_axes([0,-1.75,1.75,1.5])
ax2.set_title('Median Number of Steps Taken to Win')
ax2.set_xlabel('Agent')
ax2.set_ylabel('Steps')
ax2.set_yscale('linear')
ax2.set_yticks(range(0,36,1))
ax2.set_ylim([0,36])
ax2.bar(numNames, median_steps_to_win)

plt.show()
