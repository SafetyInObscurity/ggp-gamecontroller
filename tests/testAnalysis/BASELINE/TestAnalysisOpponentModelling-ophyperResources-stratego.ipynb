# %% [markdown]
# # <center>OP Hyper</center>
#
# This file is an interactive notebook to analyze the data obtained from tests.<br>
# The purpose of this notebook is to define a baseline for a model which can be improved upon.
# The game blind_breakthrough will be used since this seems to be the game the original hyperplay model performed the best at.
#
# **Note: It could be a good idea to look into using a stronger cheat agent for a better comparison**
#
# ## Reading in the Data
#
# First the match data must be read in.
# I will be reading in data obtained for a series of games where a hyperplayer with increasing resources competed against a CHEAT player who had access to the true state and was allowed 16 simulations per move.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import statistics
np.random.seed(42)

# Read in the csv files
numNames = ['2x2', '4x4', '8x8', '16x16']
data = list()

for idx, name in enumerate(numNames):
    file_name = 'C:/Users/Michael/VirtualBox VMs/Shared/output/stratego/ophyper_resources/' + name + '/testOutput.csv'
    data.append(pd.DataFrame)
    data[idx] = pd.read_csv(file_name, header=0)

# Read in the csv files
numNames = ['2x2', '4x4', '8x8', '16x16']
data_ahyper = list()

for idx, name in enumerate(numNames):
    file_name = 'C:/Users/Michael/VirtualBox VMs/Shared/output/stratego/ahyperlt/' + name + '/testOutput.csv'
    data_ahyper.append(pd.DataFrame)
    data_ahyper[idx] = pd.read_csv(file_name, header=0)
    
# Print the first 5 rows of the data
for game in data:
    display(game.head())
# Out:
#                                      match_id       game_name  gdl_version  \
# 0  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT            2
# 1  stratego_CHEAT_2x2ophyper_16cheat_linear_1  stratego_CHEAT            2
# 2  stratego_CHEAT_2x2ophyper_16cheat_linear_2  stratego_CHEAT            2
# 3  stratego_CHEAT_2x2ophyper_16cheat_linear_3  stratego_CHEAT            2
# 4  stratego_CHEAT_2x2ophyper_16cheat_linear_4  stratego_CHEAT            2
#
#        timestamp  startclock  playclock sight_of  num_steps role_1 player_1  \
# 0  1599483587716          10      10000      RED         29    red  OPHYPER
# 1  1599495569483          10      10000      RED         30    red  OPHYPER
# 2  1599506028986          10      10000      RED         38    red  OPHYPER
# 3  1599515385077          10      10000      RED         30    red  OPHYPER
# 4  1599519435750          10      10000      RED         36    red  OPHYPER
#
#    player_1_score role_2 player_2  player_2_score
# 0             100   blue    CHEAT               0
# 1               0   blue    CHEAT             100
# 2               0   blue    CHEAT             100
# 3               0   blue    CHEAT             100
# 4               0   blue    CHEAT             100
#                                      match_id       game_name  gdl_version  \
# 0  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT            2
# 1  stratego_CHEAT_4x4ophyper_16cheat_linear_1  stratego_CHEAT            2
# 2  stratego_CHEAT_4x4ophyper_16cheat_linear_2  stratego_CHEAT            2
# 3  stratego_CHEAT_4x4ophyper_16cheat_linear_3  stratego_CHEAT            2
# 4  stratego_CHEAT_4x4ophyper_16cheat_linear_4  stratego_CHEAT            2
#
#        timestamp  startclock  playclock sight_of  num_steps role_1 player_1  \
# 0  1599489567500          10      10000      RED         36    red  OPHYPER
# 1  1599489875682          10      10000      RED         14    red  OPHYPER
# 2  1599490687715          10      10000      RED         20    red  OPHYPER
# 3  1599492584467          10      10000      RED         24    red  OPHYPER
# 4  1599496057389          10      10000      RED         21    red  OPHYPER
#
#    player_1_score role_2 player_2  player_2_score
# 0               0   blue    CHEAT             100
# 1               0   blue    CHEAT             100
# 2               0   blue    CHEAT             100
# 3               0   blue    CHEAT             100
# 4             100   blue    CHEAT               0
#                                      match_id       game_name  gdl_version  \
# 0  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT            2
# 1  stratego_CHEAT_8x8ophyper_16cheat_linear_1  stratego_CHEAT            2
# 2  stratego_CHEAT_8x8ophyper_16cheat_linear_2  stratego_CHEAT            2
# 3  stratego_CHEAT_8x8ophyper_16cheat_linear_3  stratego_CHEAT            2
# 4  stratego_CHEAT_8x8ophyper_16cheat_linear_4  stratego_CHEAT            2
#
#        timestamp  startclock  playclock sight_of  num_steps role_1 player_1  \
# 0  1599492846639          10      10000      RED         28    red  OPHYPER
# 1  1599509703635          10      10000      RED         27    red  OPHYPER
# 2  1599513707702          10      10000      RED         24    red  OPHYPER
# 3  1599525689800          10      10000      RED         31    red  OPHYPER
# 4  1599533651221          10      10000      RED         20    red  OPHYPER
#
#    player_1_score role_2 player_2  player_2_score
# 0               0   blue    CHEAT             100
# 1             100   blue    CHEAT               0
# 2               0   blue    CHEAT             100
# 3             100   blue    CHEAT               0
# 4               0   blue    CHEAT             100
#                                        match_id       game_name  gdl_version  \
# 0  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT            2
# 1  stratego_CHEAT_16x16ophyper_16cheat_linear_1  stratego_CHEAT            2
# 2  stratego_CHEAT_16x16ophyper_16cheat_linear_2  stratego_CHEAT            2
# 3  stratego_CHEAT_16x16ophyper_16cheat_linear_3  stratego_CHEAT            2
# 4  stratego_CHEAT_16x16ophyper_16cheat_linear_4  stratego_CHEAT            2
#
#        timestamp  startclock  playclock sight_of  num_steps role_1 player_1  \
# 0  1599489295139          10      10000      RED         17    red  OPHYPER
# 1  1599496190655          10      10000      RED         18    red  OPHYPER
# 2  1599509037085          10      10000      RED         29    red  OPHYPER
# 3  1599516281045          10      10000      RED         15    red  OPHYPER
# 4  1599533445652          10      10000      RED         38    red  OPHYPER
#
#    player_1_score role_2 player_2  player_2_score
# 0             100   blue    CHEAT               0
# 1               0   blue    CHEAT             100
# 2              50   blue    CHEAT              50
# 3             100   blue    CHEAT               0
# 4               0   blue    CHEAT             100

# %% [markdown]
# Next, the move data should be read in for each match
#
# *Note: time_to_update and time_to_select_move are in milliseconds*

# %%
move_list_games = list()
for idx, name in enumerate(numNames):
    file_name_prefix = 'C:/Users/Michael/VirtualBox VMs/Shared/output/stratego/ophyper_resources/' + name + '/moveset/'
    temp_move_list = list()
    for match_name in data[idx]['match_id']:
        file_name = file_name_prefix + match_name + '.csv'
        temp_move_list.append(pd.read_csv(file_name, names=['match_id','game_name','step','role_name','player_name','count_hypergames','num_probes','time_to_update','time_to_select_move','move_chosen','last_move_illegal','numTimesMovesSimulated','numTimesHypergameForward']))
    move_list_games.append(temp_move_list)

move_list_games_ahyper = list()
for idx, name in enumerate(numNames):
    file_name_prefix = 'C:/Users/Michael/VirtualBox VMs/Shared/output/stratego/ahyperlt/' + name + '/moveset/'
    temp_move_list = list()
    for match_name in data_ahyper[idx]['match_id']:
        file_name = file_name_prefix + match_name + '.csv'
        temp_move_list.append(pd.read_csv(file_name, names=['match_id','game_name','step','role_name','player_name','count_hypergames','num_probes','time_to_update','time_to_select_move','move_chosen','last_move_illegal','numTimesMovesSimulated','numTimesHypergameForward']))
    move_list_games_ahyper.append(temp_move_list)
    
# Verify by printing the head of the first game
for move_list in move_list_games:
    display(move_list[0])
# Out:
#                                       match_id       game_name  step  \
# 0   stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     0
# 1   stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     0
# 2   stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     1
# 3   stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     1
# 4   stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     2
# 5   stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     2
# 6   stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     3
# 7   stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     3
# 8   stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     4
# 9   stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     4
# 10  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     5
# 11  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     5
# 12  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     6
# 13  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     6
# 14  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     7
# 15  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     7
# 16  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     8
# 17  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     8
# 18  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     9
# 19  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT     9
# 20  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    10
# 21  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    10
# 22  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    11
# 23  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    11
# 24  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    12
# 25  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    12
# 26  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    13
# 27  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    13
# 28  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    14
# 29  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    14
# 30  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    15
# 31  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    15
# 32  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    16
# 33  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    16
# 34  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    17
# 35  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    17
# 36  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    18
# 37  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    18
# 38  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    19
# 39  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    19
# 40  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    20
# 41  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    20
# 42  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    21
# 43  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    21
# 44  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    22
# 45  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    22
# 46  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    23
# 47  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    23
# 48  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    24
# 49  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    24
# 50  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    25
# 51  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    25
# 52  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    26
# 53  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    26
# 54  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    27
# 55  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    27
# 56  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    28
# 57  stratego_CHEAT_2x2ophyper_16cheat_linear_0  stratego_CHEAT    28
#
#    role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0        RED     ophyper                 1           2              18
# 1       BLUE       cheat                 1          16              13
# 2       BLUE       cheat                 1          16              16
# 3        RED     ophyper                 2           2           18707
# 4       BLUE       cheat                 1          16               7
# 5        RED     ophyper                 2           2           25356
# 6       BLUE       cheat                 1          16               6
# 7        RED     ophyper                 2           2           20301
# 8       BLUE       cheat                 1          16               9
# 9        RED     ophyper                 2           2           14994
# 10      BLUE       cheat                 1          16               7
# 11       RED     ophyper                 2           2            9596
# 12      BLUE       cheat                 1          16               6
# 13       RED     ophyper                 2           2            5388
# 14       RED     ophyper                 2           2            7599
# 15      BLUE       cheat                 1          16              20
# 16      BLUE       cheat                 1          16              12
# 17       RED     ophyper                 2           2           42928
# 18       RED     ophyper                 2           2            6611
# 19      BLUE       cheat                 1          16              15
# 20      BLUE       cheat                 1          16              15
# 21       RED     ophyper                 2           2           24355
# 22       RED     ophyper                 2           2            6403
# 23      BLUE       cheat                 1          16              19
# 24      BLUE       cheat                 1          16              10
# 25       RED     ophyper                 2           2          514442
# 26       RED     ophyper                 2           2            6623
# 27      BLUE       cheat                 1          16              39
# 28      BLUE       cheat                 1          16              10
# 29       RED     ophyper                 2           2           27453
# 30       RED     ophyper                 2           2            6287
# 31      BLUE       cheat                 1          16              23
# 32      BLUE       cheat                 1          16               5
# 33       RED     ophyper                 2           2           18871
# 34       RED     ophyper                 2           2            5441
# 35      BLUE       cheat                 1          16              13
# 36      BLUE       cheat                 1          16               5
# 37       RED     ophyper                 2           2           35808
# 38      BLUE       cheat                 1          16              43
# 39       RED     ophyper                 2           2            3830
# 40      BLUE       cheat                 1          16               5
# 41       RED     ophyper                 2           2          582615
# 42       RED     ophyper                 2           2            4362
# 43      BLUE       cheat                 1          16              37
# 44      BLUE       cheat                 1          16               6
# 45       RED     ophyper                 2           2          218752
# 46      BLUE       cheat                 1          16              36
# 47       RED     ophyper                 2           2            4212
# 48      BLUE       cheat                 1          16               7
# 49       RED     ophyper                 2           2            6651
# 50       RED     ophyper                 2           2            4177
# 51      BLUE       cheat                 1          16              23
# 52      BLUE       cheat                 1          16               6
# 53       RED     ophyper                 2           2          731507
# 54      BLUE       cheat                 1          16              12
# 55       RED     ophyper                 2           2            3302
# 56      BLUE       cheat                 1          16              11
# 57       RED     ophyper                 2           2            4214
#
#     time_to_select_move           move_chosen  last_move_illegal  \
# 0                  4283     (PLACE 1 1 FLAG )              False
# 1                 12599     (PLACE 1 5 FLAG )              False
# 2                 15881    (PLACE 2 5 SCOUT )              False
# 3                  2468    (PLACE 2 1 SCOUT )              False
# 4                 13267     (PLACE 3 5 BOMB )              False
# 5                  1914  (PLACE 3 1 MARSHAL )              False
# 6                  9530      (PLACE 1 6 SPY )              False
# 7                  1572     (PLACE 1 2 BOMB )              False
# 8                  6741  (PLACE 2 6 MARSHAL )              False
# 9                  1015    (PLACE 2 2 MINER )              False
# 10                 3226    (PLACE 3 6 MINER )              False
# 11                    0      (PLACE 3 2 SPY )              False
# 12                 2916                  NOOP              False
# 13                  949       (MOVE 3 2 3 3 )              False
# 14                    0                  NOOP              False
# 15                10575       (MOVE 2 5 2 4 )              False
# 16                 3233                  NOOP              False
# 17                 2811       (MOVE 2 2 3 2 )              False
# 18                    0                  NOOP              False
# 19                16542       (MOVE 2 4 2 5 )              False
# 20                 3084                  NOOP              False
# 21                 2250       (MOVE 3 3 2 3 )              False
# 22                    0                  NOOP              False
# 23                 8855       (MOVE 2 5 3 4 )              False
# 24                 2859                  NOOP              False
# 25                 2955       (MOVE 2 1 2 2 )              False
# 26                    0                  NOOP              False
# 27                12890       (MOVE 3 4 2 5 )              False
# 28                 2744                  NOOP              False
# 29                 2516       (MOVE 3 1 2 1 )              False
# 30                    0                  NOOP              False
# 31                 8789       (MOVE 2 5 2 3 )              False
# 32                 2513                  NOOP              False
# 33                 1502       (MOVE 2 1 3 1 )              False
# 34                    0                  NOOP              False
# 35                15613       (MOVE 2 3 3 2 )              False
# 36                 2172                  NOOP              False
# 37                 2350       (MOVE 3 2 3 3 )              False
# 38                 2325       (MOVE 2 6 2 5 )              False
# 39                    0                  NOOP              False
# 40                 2064                  NOOP              False
# 41                 2893       (MOVE 3 3 3 2 )              False
# 42                    0                  NOOP              False
# 43                 6647       (MOVE 3 6 2 6 )              False
# 44                 1888                  NOOP              False
# 45                 1712       (MOVE 2 2 2 1 )              False
# 46                 4165       (MOVE 2 6 3 6 )              False
# 47                    0                  NOOP              False
# 48                 1991                  NOOP              False
# 49                 1146       (MOVE 2 1 2 2 )              False
# 50                    0                  NOOP              False
# 51                 5841       (MOVE 1 6 2 6 )              False
# 52                 1780                  NOOP              False
# 53                 1784       (MOVE 2 2 1 3 )              False
# 54                 2776       (MOVE 2 6 1 6 )              False
# 55                    0                  NOOP              False
# 56                 1372                  NOOP              False
# 57                 1952       (MOVE 1 3 1 5 )              False
#
#     numTimesMovesSimulated  numTimesHypergameForward
# 0                       12                         0
# 1                       90                         0
# 2                       75                         1
# 3                      116                         2
# 4                       60                         2
# 5                      176                         2
# 6                       45                         1
# 7                      140                         2
# 8                       30                         3
# 9                      104                         2
# 10                      15                         2
# 11                      64                         2
# 12                      15                         1
# 13                      40                         2
# 14                      32                         2
# 15                      60                         2
# 16                      15                         1
# 17                     376                        15
# 18                      32                         2
# 19                     120                         2
# 20                      15                         1
# 21                     228                         7
# 22                      32                         2
# 23                      60                         2
# 24                      15                         1
# 25                    4348                       243
# 26                      32                         2
# 27                     105                         6
# 28                      15                         1
# 29                     280                        10
# 30                      32                         2
# 31                      60                         2
# 32                      15                         1
# 33                     192                         5
# 34                      32                         2
# 35                     150                         1
# 36                      15                         1
# 37                     412                         5
# 38                      15                         7
# 39                      32                         2
# 40                      15                         1
# 41                    5368                       258
# 42                      32                         2
# 43                      60                         5
# 44                      15                         1
# 45                    2188                       114
# 46                      30                         6
# 47                      32                         2
# 48                      15                         1
# 49                      96                         5
# 50                      32                         2
# 51                      60                         4
# 52                      15                         1
# 53                    6796                       363
# 54                      30                         2
# 55                      32                         2
# 56                      15                         1
# 57                     100                         3
#                                       match_id       game_name  step  \
# 0   stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     0
# 1   stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     0
# 2   stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     1
# 3   stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     1
# 4   stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     2
# 5   stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     2
# 6   stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     3
# 7   stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     3
# 8   stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     4
# 9   stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     4
# 10  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     5
# 11  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     5
# 12  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     6
# 13  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     6
# 14  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     7
# 15  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     7
# 16  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     8
# 17  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     8
# 18  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     9
# 19  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT     9
# 20  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    10
# 21  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    10
# 22  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    11
# 23  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    11
# 24  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    12
# 25  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    12
# 26  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    13
# 27  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    13
# 28  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    14
# 29  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    14
# ..                                         ...             ...   ...
# 42  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    21
# 43  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    21
# 44  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    22
# 45  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    22
# 46  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    23
# 47  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    23
# 48  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    24
# 49  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    24
# 50  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    25
# 51  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    25
# 52  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    26
# 53  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    26
# 54  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    27
# 55  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    27
# 56  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    28
# 57  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    28
# 58  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    29
# 59  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    29
# 60  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    30
# 61  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    30
# 62  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    31
# 63  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    31
# 64  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    32
# 65  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    32
# 66  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    33
# 67  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    33
# 68  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    34
# 69  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    34
# 70  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    35
# 71  stratego_CHEAT_4x4ophyper_16cheat_linear_0  stratego_CHEAT    35
#
#    role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0        RED     ophyper                 1           4              17
# 1       BLUE       cheat                 1          16              14
# 2       BLUE       cheat                 1          16              27
# 3        RED     ophyper                 4           4           15929
# 4       BLUE       cheat                 1          16               5
# 5        RED     ophyper                 4           4           31776
# 6       BLUE       cheat                 1          16               4
# 7        RED     ophyper                 4           4           27482
# 8       BLUE       cheat                 1          16              12
# 9        RED     ophyper                 4           4           20292
# 10      BLUE       cheat                 1          16               4
# 11       RED     ophyper                 4           4           13012
# 12      BLUE       cheat                 1          16               7
# 13       RED     ophyper                 4           4            7426
# 14      BLUE       cheat                 1          16              33
# 15       RED     ophyper                 4           4            9888
# 16      BLUE       cheat                 1          16              16
# 17       RED     ophyper                 4           4           64143
# 18      BLUE       cheat                 1          16              29
# 19       RED     ophyper                 4           4          107985
# 20      BLUE       cheat                 1          16               6
# 21       RED     ophyper                 4           4           26216
# 22       RED     ophyper                 4           4           11010
# 23      BLUE       cheat                 1          16              15
# 24      BLUE       cheat                 1          16              10
# 25       RED     ophyper                 4           4           29092
# 26      BLUE       cheat                 1          16              30
# 27       RED     ophyper                 4           4            8595
# 28      BLUE       cheat                 1          16               6
# 29       RED     ophyper                 4           4           16461
# ..       ...         ...               ...         ...             ...
# 42      BLUE       cheat                 1          16              20
# 43       RED     ophyper                 4           4            6221
# 44      BLUE       cheat                 1          16              15
# 45       RED     ophyper                 4           4            9850
# 46      BLUE       cheat                 1          16              41
# 47       RED     ophyper                 1           4         1007655
# 48      BLUE       cheat                 1          16               4
# 49       RED     ophyper                 1           4         1005660
# 50      BLUE       cheat                 1          16              14
# 51       RED     ophyper                 3           4         1006577
# 52      BLUE       cheat                 1          16               7
# 53       RED     ophyper                 4           4          366973
# 54       RED     ophyper                 4           4            6391
# 55      BLUE       cheat                 1          16               6
# 56      BLUE       cheat                 1          16              10
# 57       RED     ophyper                 4           4           20254
# 58       RED     ophyper                 4           4            5699
# 59      BLUE       cheat                 1          16              26
# 60      BLUE       cheat                 1          16               7
# 61       RED     ophyper                 4           4           18349
# 62       RED     ophyper                 4           4            5170
# 63      BLUE       cheat                 1          16               9
# 64      BLUE       cheat                 1          16               4
# 65       RED     ophyper                 1           4         1004581
# 66      BLUE       cheat                 1          16              10
# 67       RED     ophyper                 1           4         1004155
# 68      BLUE       cheat                 1          16               7
# 69       RED     ophyper                 1           4         1037405
# 70      BLUE       cheat                 1          16               7
# 71       RED     ophyper                 2           4         1006655
#
#     time_to_select_move           move_chosen  last_move_illegal  \
# 0                  5335  (PLACE 1 1 MARSHAL )              False
# 1                 11506    (PLACE 1 5 MINER )              False
# 2                 13899    (PLACE 2 5 SCOUT )              False
# 3                  6417     (PLACE 2 1 FLAG )              False
# 4                 11441  (PLACE 3 5 MARSHAL )              False
# 5                  5783     (PLACE 3 1 BOMB )              False
# 6                  9315     (PLACE 1 6 BOMB )              False
# 7                  4291    (PLACE 1 2 MINER )              False
# 8                  6091     (PLACE 2 6 FLAG )              False
# 9                  2885    (PLACE 2 2 SCOUT )              False
# 10                 3131      (PLACE 3 6 SPY )              False
# 11                    0      (PLACE 3 2 SPY )              False
# 12                 2819                  NOOP              False
# 13                 8162       (MOVE 2 2 2 4 )              False
# 14                 8196       (MOVE 1 5 1 4 )              False
# 15                    0                  NOOP              False
# 16                 2697                  NOOP              False
# 17                15433       (MOVE 2 4 2 5 )              False
# 18                12586       (MOVE 1 4 2 4 )              False
# 19                    0                  NOOP              False
# 20                 2537                  NOOP              False
# 21                 4583       (MOVE 1 2 2 2 )              False
# 22                    0                  NOOP              False
# 23                12448       (MOVE 2 4 3 4 )              False
# 24                 2306                  NOOP              False
# 25                 4633       (MOVE 1 1 1 2 )              False
# 26                 7121       (MOVE 3 4 3 3 )              False
# 27                    0                  NOOP              False
# 28                 2178                  NOOP              False
# 29                 4060       (MOVE 1 2 1 3 )              False
# ..                  ...                   ...                ...
# 42                 4869       (MOVE 3 5 2 5 )              False
# 43                    0                  NOOP              False
# 44                 1772                  NOOP              False
# 45                 5726       (MOVE 1 5 1 6 )              False
# 46                11557       (MOVE 3 6 3 5 )              False
# 47                    0                  NOOP              False
# 48                 1592                  NOOP              False
# 49                 1126       (MOVE 2 3 2 2 )              False
# 50                 7442       (MOVE 3 5 3 6 )              False
# 51                    0                  NOOP              False
# 52                 1605                  NOOP              False
# 53                 2191       (MOVE 2 2 1 2 )              False
# 54                    0                  NOOP              False
# 55                 7991       (MOVE 3 4 3 3 )              False
# 56                 1299                  NOOP              False
# 57                 3192       (MOVE 3 2 2 2 )              False
# 58                    0                  NOOP              False
# 59                 7113       (MOVE 2 5 2 4 )              False
# 60                 1215                  NOOP              False
# 61                 2340       (MOVE 2 2 3 2 )              False
# 62                    0                  NOOP              False
# 63                 6836       (MOVE 3 3 3 2 )              False
# 64                  946                  NOOP              False
# 65                  298       (MOVE 1 2 1 3 )              False
# 66                 7254       (MOVE 3 2 3 1 )              False
# 67                    1                  NOOP              False
# 68                  617                  NOOP              False
# 69                  175       (MOVE 1 3 1 4 )              False
# 70                 3703       (MOVE 3 1 2 1 )              False
# 71                    0                  NOOP              False
#
#     numTimesMovesSimulated  numTimesHypergameForward
# 0                       24                         0
# 1                       90                         0
# 2                       75                         2
# 3                      176                         4
# 4                       60                         2
# 5                      384                         4
# 6                       45                         1
# 7                      304                         4
# 8                       30                         2
# 9                      224                         4
# 10                      15                         1
# 11                     128                         4
# 12                      15                         1
# 13                     160                         4
# 14                      45                         5
# 15                      64                         4
# 16                      15                         1
# 17                     944                        39
# 18                      75                         4
# 19                    1216                        72
# 20                      15                         1
# 21                     384                        19
# 22                      64                         4
# 23                      90                         2
# 24                      15                         1
# 25                     448                        10
# 26                      45                         4
# 27                      64                         4
# 28                      15                         1
# 29                     288                         7
# ..                     ...                       ...
# 42                      45                         4
# 43                      64                         4
# 44                      15                         1
# 45                     368                        10
# 46                     105                         6
# 47                   13024                       944
# 48                      15                         1
# 49                   13656                      1137
# 50                      75                         1
# 51                   13328                      1355
# 52                      15                         1
# 53                    5136                       570
# 54                      64                         4
# 55                     105                         1
# 56                      15                         1
# 57                     528                        16
# 58                      64                         4
# 59                     105                         3
# 60                      15                         1
# 61                     512                        20
# 62                      64                         4
# 63                     120                         2
# 64                      15                         1
# 65                   14028                      1831
# 66                     120                         1
# 67                   14080                      2184
# 68                      15                         1
# 69                   14668                      2976
# 70                     105                         1
# 71                   14432                      4033
#
# [72 rows x 13 columns]
#                                       match_id       game_name  step  \
# 0   stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     0
# 1   stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     0
# 2   stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     1
# 3   stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     1
# 4   stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     2
# 5   stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     2
# 6   stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     3
# 7   stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     3
# 8   stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     4
# 9   stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     4
# 10  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     5
# 11  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     5
# 12  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     6
# 13  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     6
# 14  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     7
# 15  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     7
# 16  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     8
# 17  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     8
# 18  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     9
# 19  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT     9
# 20  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    10
# 21  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    10
# 22  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    11
# 23  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    11
# 24  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    12
# 25  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    12
# 26  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    13
# 27  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    13
# 28  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    14
# 29  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    14
# 30  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    15
# 31  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    15
# 32  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    16
# 33  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    16
# 34  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    17
# 35  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    17
# 36  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    18
# 37  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    18
# 38  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    19
# 39  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    19
# 40  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    20
# 41  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    20
# 42  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    21
# 43  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    21
# 44  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    22
# 45  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    22
# 46  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    23
# 47  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    23
# 48  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    24
# 49  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    24
# 50  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    25
# 51  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    25
# 52  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    26
# 53  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    26
# 54  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    27
# 55  stratego_CHEAT_8x8ophyper_16cheat_linear_0  stratego_CHEAT    27
#
#    role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0        RED     ophyper                 1           8              37
# 1       BLUE       cheat                 1          16              15
# 2       BLUE       cheat                 1          16              23
# 3        RED     ophyper                 6           8           18359
# 4       BLUE       cheat                 1          16              17
# 5        RED     ophyper                 8           8           59563
# 6       BLUE       cheat                 1          16               4
# 7        RED     ophyper                 8           8           64084
# 8       BLUE       cheat                 1          16               8
# 9        RED     ophyper                 8           8           47639
# 10      BLUE       cheat                 1          16              21
# 11       RED     ophyper                 8           8           30063
# 12      BLUE       cheat                 1          16              11
# 13       RED     ophyper                 8           8           15710
# 14      BLUE       cheat                 1          16               8
# 15       RED     ophyper                 8           8           20230
# 16      BLUE       cheat                 1          16               9
# 17       RED     ophyper                 8           8          557657
# 18       RED     ophyper                 8           8           23019
# 19      BLUE       cheat                 1          16               9
# 20      BLUE       cheat                 1          16              10
# 21       RED     ophyper                 8           8           97936
# 22      BLUE       cheat                 1          16              19
# 23       RED     ophyper                 3           8         1007853
# 24      BLUE       cheat                 1          16               7
# 25       RED     ophyper                 4           8         1002315
# 26      BLUE       cheat                 1          16              14
# 27       RED     ophyper                 6           8         1000500
# 28      BLUE       cheat                 1          16              11
# 29       RED     ophyper                 7           8         1000296
# 30      BLUE       cheat                 1          16              34
# 31       RED     ophyper                 8           8          319738
# 32      BLUE       cheat                 1          16               8
# 33       RED     ophyper                 8           8           45081
# 34      BLUE       cheat                 1          16              12
# 35       RED     ophyper                 4           8         1052804
# 36      BLUE       cheat                 1          16               5
# 37       RED     ophyper                 6           8         1016006
# 38      BLUE       cheat                 1          16               5
# 39       RED     ophyper                 6           8         1014963
# 40      BLUE       cheat                 1          16               6
# 41       RED     ophyper                 6           8         1006353
# 42      BLUE       cheat                 1          16               7
# 43       RED     ophyper                 6           8         1003460
# 44      BLUE       cheat                 1          16               9
# 45       RED     ophyper                 6           8          957357
# 46      BLUE       cheat                 1          16              17
# 47       RED     ophyper                 6           8           10896
# 48      BLUE       cheat                 1          16               7
# 49       RED     ophyper                 4           8           37115
# 50       RED     ophyper                 4           8            8172
# 51      BLUE       cheat                 1          16              22
# 52      BLUE       cheat                 1          16               6
# 53       RED     ophyper                 4           8           25241
# 54       RED     ophyper                 4           8            7284
# 55      BLUE       cheat                 1          16               8
#
#     time_to_select_move           move_chosen  last_move_illegal  \
# 0                 10992    (PLACE 1 1 SCOUT )              False
# 1                 15532  (PLACE 1 5 MARSHAL )              False
# 2                 15849     (PLACE 2 5 BOMB )              False
# 3                 26560     (PLACE 2 1 FLAG )              False
# 4                 13427    (PLACE 3 5 SCOUT )              False
# 5                 29628    (PLACE 3 1 MINER )              False
# 6                 10787     (PLACE 1 6 FLAG )              False
# 7                 22108  (PLACE 1 2 MARSHAL )              False
# 8                  6759    (PLACE 2 6 MINER )              False
# 9                 14256     (PLACE 2 2 BOMB )              False
# 10                 3302      (PLACE 3 6 SPY )              False
# 11                    0      (PLACE 3 2 SPY )              False
# 12                 3316                  NOOP              False
# 13                13536       (MOVE 1 2 1 3 )              False
# 14                12422       (MOVE 3 5 3 3 )              False
# 15                    0                  NOOP              False
# 16                 2906                  NOOP              False
# 17                30417       (MOVE 1 3 1 4 )              False
# 18                    0                  NOOP              False
# 19                23858       (MOVE 3 3 3 2 )              False
# 20                 2643                  NOOP              False
# 21                29193       (MOVE 1 4 1 5 )              False
# 22                13516       (MOVE 3 2 3 3 )              False
# 23                    0                  NOOP              False
# 24                 1986                  NOOP              False
# 25                 7758       (MOVE 1 1 1 2 )              False
# 26                19661       (MOVE 3 3 3 5 )              False
# 27                    0                  NOOP              False
# 28                 1953                  NOOP              False
# 29                22074       (MOVE 1 2 1 4 )              False
# 30                 4993       (MOVE 3 5 2 4 )              False
# 31                    0                  NOOP              False
# 32                 1850                  NOOP              False
# 33                34905       (MOVE 1 4 2 5 )              False
# 34                17670       (MOVE 2 4 3 3 )              False
# 35                    0                  NOOP              False
# 36                 1996                  NOOP              False
# 37                    0       (MOVE 3 1 3 2 )              False
# 38                13386       (MOVE 3 3 3 4 )              False
# 39                    0                  NOOP              False
# 40                 1730                  NOOP              False
# 41                 5974       (MOVE 3 2 3 3 )              False
# 42                 9446       (MOVE 3 4 1 4 )              False
# 43                    0                  NOOP              False
# 44                 1527                  NOOP              False
# 45                 8054       (MOVE 3 3 3 4 )              False
# 46                 8504       (MOVE 3 6 3 5 )              False
# 47                    0                  NOOP              False
# 48                 1200                  NOOP              False
# 49                 4689       (MOVE 3 4 2 4 )              False
# 50                    0                  NOOP              False
# 51                 8868       (MOVE 1 4 1 2 )              False
# 52                  995                  NOOP              False
# 53                 4879       (MOVE 2 4 2 3 )              False
# 54                    0                  NOOP              False
# 55                 8031       (MOVE 1 2 2 1 )              False
#
#     numTimesMovesSimulated  numTimesHypergameForward
# 0                       48                         0
# 1                       90                         0
# 2                       75                         2
# 3                      336                         6
# 4                       60                         4
# 5                      736                        10
# 6                       45                         1
# 7                      704                         8
# 8                       30                         2
# 9                      512                         8
# 10                      15                         2
# 11                     256                         8
# 12                      15                         1
# 13                     256                         8
# 14                      60                         1
# 15                     128                         8
# 16                      15                         1
# 17                    5440                       317
# 18                     128                         8
# 19                     135                         1
# 20                      15                         1
# 21                    1568                        35
# 22                      90                         3
# 23                    9488                       760
# 24                      15                         1
# 25                    9680                       818
# 26                     135                         2
# 27                    9392                      1042
# 28                      15                         1
# 29                   10056                      1127
# 30                      45                         5
# 31                    3040                       340
# 32                      15                         1
# 33                    1120                        26
# 34                     135                         1
# 35                   10416                      1360
# 36                      15                         1
# 37                   10320                      1315
# 38                     120                         1
# 39                   10336                      1716
# 40                      15                         1
# 41                   10496                      1948
# 42                      90                         1
# 43                   10656                      3116
# 44                      15                         1
# 45                   11184                      3875
# 46                     105                         3
# 47                      96                       884
# 48                      15                         1
# 49                     800                       951
# 50                      64                       698
# 51                     120                         3
# 52                      15                         1
# 53                     640                       783
# 54                      64                       810
# 55                     135                         1
#                                         match_id       game_name  step  \
# 0   stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     0
# 1   stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     0
# 2   stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     1
# 3   stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     1
# 4   stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     2
# 5   stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     2
# 6   stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     3
# 7   stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     3
# 8   stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     4
# 9   stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     4
# 10  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     5
# 11  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     5
# 12  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     6
# 13  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     6
# 14  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     7
# 15  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     7
# 16  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     8
# 17  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     8
# 18  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     9
# 19  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT     9
# 20  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    10
# 21  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    10
# 22  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    11
# 23  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    11
# 24  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    12
# 25  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    12
# 26  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    13
# 27  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    13
# 28  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    14
# 29  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    14
# 30  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    15
# 31  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    15
# 32  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    16
# 33  stratego_CHEAT_16x16ophyper_16cheat_linear_0  stratego_CHEAT    16
#
#    role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0       BLUE       cheat                 1          16               4
# 1        RED     ophyper                 1          16              11
# 2       BLUE       cheat                 1          16              16
# 3        RED     ophyper                 6          16           17686
# 4       BLUE       cheat                 1          16              15
# 5        RED     ophyper                16          16           60347
# 6       BLUE       cheat                 1          16              15
# 7        RED     ophyper                16          16          122593
# 8       BLUE       cheat                 1          16              13
# 9        RED     ophyper                16          16           93902
# 10      BLUE       cheat                 1          16               8
# 11       RED     ophyper                16          16           63065
# 12      BLUE       cheat                 1          16               7
# 13       RED     ophyper                16          16           31098
# 14      BLUE       cheat                 1          16              22
# 15       RED     ophyper                16          16           32554
# 16      BLUE       cheat                 1          16               9
# 17       RED     ophyper                16          16          294771
# 18      BLUE       cheat                 1          16              45
# 19       RED     ophyper                16          16           34976
# 20      BLUE       cheat                 1          16               9
# 21       RED     ophyper                16          16          609035
# 22      BLUE       cheat                 1          16              19
# 23       RED     ophyper                 4          16         1021858
# 24      BLUE       cheat                 1          16               5
# 25       RED     ophyper                 1          16         1012970
# 26      BLUE       cheat                 1          16              10
# 27       RED     ophyper                 2          16         1022170
# 28      BLUE       cheat                 1          16              10
# 29       RED     ophyper                 2          16         1006599
# 30      BLUE       cheat                 1          16              27
# 31       RED     ophyper                 2          16         1005923
# 32      BLUE       cheat                 1          16               8
# 33       RED     ophyper                 1          16         1005377
#
#     time_to_select_move           move_chosen  last_move_illegal  \
# 0                 20458      (PLACE 1 5 SPY )              False
# 1                 20796     (PLACE 1 1 BOMB )              False
# 2                 15125    (PLACE 2 5 MINER )              False
# 3                 51061     (PLACE 2 1 FLAG )              False
# 4                 13313  (PLACE 3 5 MARSHAL )              False
# 5                119684    (PLACE 3 1 SCOUT )              False
# 6                 10286    (PLACE 1 6 SCOUT )              False
# 7                 91310    (PLACE 1 2 MINER )              False
# 8                  6878     (PLACE 2 6 BOMB )              False
# 9                 59248  (PLACE 2 2 MARSHAL )              False
# 10                 3131     (PLACE 3 6 FLAG )              False
# 11                    0      (PLACE 3 2 SPY )              False
# 12                 3366                  NOOP              False
# 13                85338       (MOVE 1 2 1 3 )              False
# 14                 9341       (MOVE 3 5 3 4 )              False
# 15                    0                  NOOP              False
# 16                 2998                  NOOP              False
# 17               160204       (MOVE 1 3 1 4 )              False
# 18                16440       (MOVE 2 5 3 5 )              False
# 19                    0                  NOOP              False
# 20                 2565                  NOOP              False
# 21               137150       (MOVE 1 4 1 5 )              False
# 22                10453       (MOVE 1 6 1 5 )              False
# 23                    0                  NOOP              False
# 24                 2349                  NOOP              False
# 25                 7507       (MOVE 1 5 1 6 )              False
# 26                 6469       (MOVE 3 4 3 3 )              False
# 27                    0                  NOOP              False
# 28                 2160                  NOOP              False
# 29                 9199       (MOVE 1 6 2 6 )              False
# 30                 6264       (MOVE 3 3 3 2 )              False
# 31                    0                  NOOP              False
# 32                 1078                  NOOP              False
# 33                 3871       (MOVE 2 6 3 6 )              False
#
#     numTimesMovesSimulated  numTimesHypergameForward
# 0                       90                         0
# 1                       96                         0
# 2                       75                         1
# 3                      576                         6
# 4                       60                         4
# 5                     1504                        26
# 6                       45                         4
# 7                     1792                        16
# 8                       30                         2
# 9                     1280                        16
# 10                      15                         1
# 11                     512                        16
# 12                      15                         1
# 13                    1024                        16
# 14                      45                         2
# 15                     256                        16
# 16                      15                         1
# 17                    4192                       150
# 18                      90                         6
# 19                     256                        16
# 20                      15                         1
# 21                    7360                       381
# 22                      60                         2
# 23                    9568                       749
# 24                      15                         1
# 25                    9856                       716
# 26                      45                         1
# 27                    9792                       908
# 28                      15                         1
# 29                    9872                       958
# 30                      75                         2
# 31                    9584                      1106
# 32                      15                         1
# 33                    9920                      1152

# %% [markdown]
# ## Analysis of Data
#
# ### Overall Agent Results
#
# The average score of the agent will be calculated across all games

# %%
count_games_completed = list()
total_score_ophyper = list()
for idx, game in enumerate(data):
    total_score = data[idx]['player_1_score'][data[idx]['player_1_score'] >= 50].count() * 100
    total_count = len(data[idx]['player_1_score'])
    count_games_completed.append(total_count)
    total_score_ophyper.append(total_score)
    print(f"The win/draw rate for the agent \"" + str(data[idx]['player_1'][0]) + "\" playing the game \"" + str(data[idx]['game_name'][0]) + "\" with " + str(numNames[idx]) + f" probes is {(total_score/total_count):.2f}% for " + str(total_count) + " games")

# calc results for ahyper
win_count_ahyper = list()
total_score_ahyper = list()
for idx, game in enumerate(data_ahyper):
    total_score = data_ahyper[idx]['player_1_score'][data_ahyper[idx]['player_1_score'] >= 50].count() * 100
    total_score_ahyper.append(total_score)
    game_count = [len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 0)]), len(game[(game['player_1_score'] == 0) & (game['player_2_score'] == 100)]), len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)])]
    win_count_ahyper.append(game_count[0])
    
# Display a pie chart
fig = plt.figure()
data_len = len(data)
win_count = list()
for idx, game in enumerate(data):
    ax = fig.add_axes([(data_len - idx)%2,math.ceil((data_len - idx)/2),1,1])
    ax.axis('equal')
    ax.set_title('Win rate for ' + str(numNames[idx]))
    result = ['Won', 'Lost', 'Drew']
    game_count = [len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 0)]), len(game[(game['player_1_score'] == 0) & (game['player_2_score'] == 100)]), len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)])]
    win_count.append(game_count[0])
    ax.pie(game_count, labels = result,autopct='%1.1f%%')
plt.show()
# Out:
# The win/draw rate for the agent "OPHYPER" playing the game "stratego_CHEAT" with 2x2 probes is 15.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "stratego_CHEAT" with 4x4 probes is 32.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "stratego_CHEAT" with 8x8 probes is 39.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "stratego_CHEAT" with 16x16 probes is 50.00% for 100 games

# %% [markdown]
# It is now worth looking into how performance degrades with fewer probes.
#
# First I will consider the number of games that can be completed without error compared to the number of probes.

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2], label='state_update')
ax1.set_title('Number of Games Completed')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Games Completed')
ax1.set_yscale('linear')
ax1.set_ylim([0,101])
ax1.bar(numNames, count_games_completed, color=u'#ff7f0e')
plt.show()

# %% [markdown]
# I will now consider whether the number of games won

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Proportion of Games Won that were Completed')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Games Won')
ax1.set_yscale('linear')
ax1.set_yticks(np.linspace(0, 100, 21))
ax1.set_ylim([0,100])
nobias_line, = ax1.plot(numNames, np.divide(total_score_ophyper,count_games_completed), marker='o', color=u'#ff7f0e')
plt.show()

# %% [markdown]
# Compared to ahyperlt

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Overall Score Against Number of Resources')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Overall Score')
ax1.set_yscale('linear')
ax1.set_yticks(np.linspace(0, 100, 21))
ax1.set_ylim([0,100])
ahyper_line, = ax1.plot(numNames, np.divide(total_score_ahyper,count_games_completed), marker='o')
poly1d_fn_ahyper = np.poly1d(np.polyfit([0, 1, 2, 3], np.divide(total_score_ahyper,count_games_completed), 1))
ahyper_fit, = ax1.plot(numNames, poly1d_fn_ahyper([0, 1, 2, 3]))
nobias_line, = ax1.plot(numNames, np.divide(total_score_ophyper,count_games_completed), marker='o')
poly1d_fn_nobias = np.poly1d(np.polyfit([0, 1, 2, 3], np.divide(total_score_ophyper,count_games_completed), 1))
nobias_fit, = ax1.plot(numNames, poly1d_fn_nobias([0, 1, 2, 3]))
ax1.legend((nobias_line, nobias_fit, ahyper_line, ahyper_fit), ('Opponent Modelling', 'Opponent Modelling Regression', 'Original Hyperplay', 'Original Hyperplay Regression'))
plt.show()

np.divide(total_score_ophyper,count_games_completed)
# Out:
# array([15., 32., 39., 50.])

# %% [markdown]
# ### Move Results
#
# Calculating the average move time per game.
# This is expected to grow with the depth of the game and is expected to be different for the state update and the move selection.

# %%
class Tracker:
    '''
    Tracker tracks the average time for each move of each game played
    '''
    def __init__(self):
        self.time_sum = 0
        self.num_moves = 0
        self.times = list()
    
    def __str__(self):
        return "time_sum: " + str(self.time_sum) + " ms\n\tnum_moves: " + str(self.num_moves) + "\n\tmean_time: " + str(statistics.mean(self.times)) + "\n\tmedian_time: " + str(statistics.median(self.times)) + " ms\n\ttimes (ms): " + str(self.times)
    
    def addMove(self, num):
        self.time_sum += num
        self.num_moves+=1
        self.times.append(num)
    
    def getMeanTime(self):
        return statistics.mean(self.times)
    
    def getMedianTime(self):
        return statistics.median(self.times)

# Add the results for each move of each game played to a list of trackers for the update and select move times for the chosen player
time_to_update_list = list()
time_to_select_move_list = list()
max_num_steps = [0] * len(numNames)
for idx, (move_list, game) in enumerate(zip(move_list_games, data)):
    temp_time_to_update_list = list()
    temp_time_to_select_move_list = list()
    player_name = game['role_1'][0].upper()
    for move_set in move_list:
        for index, move_row in move_set.iterrows():
            if move_row['role_name'] == player_name:
                if move_row['step'] > len(temp_time_to_update_list) - 1:
                    max_num_steps[idx] += 1
                    temp_time_to_update_list.append(Tracker())
                    temp_time_to_select_move_list.append(Tracker())
                temp_time_to_update_list[move_row['step']].addMove(move_row['time_to_update'])
                temp_time_to_select_move_list[move_row['step']].addMove(move_row['time_to_select_move'])
    time_to_update_list.append(temp_time_to_update_list)
    time_to_select_move_list.append(temp_time_to_select_move_list)

# Print the data
for game_num, (game_time_to_update_list, game_time_to_select_move_list) in enumerate(zip(time_to_update_list, time_to_select_move_list)):
    print(str(numNames[game_num]))
    for idx, (update_step, select_step) in enumerate(zip(game_time_to_update_list, game_time_to_select_move_list)):
        print('\tStep: ' + str(idx) + "\n")
        print('\tTime taken to update states:')
        print('\t' + str(update_step)  + "\n")
        print('\tTime taken to select move:')
        print('\t' + str(select_step)  + "\n\n\n")

# %% [markdown]
# Now I will graph the findings

# %%
# Add the data to an array
mean_state_update_times = list()
mean_move_select_times = list()
median_state_update_times = list()
median_move_select_times = list()
for game_num, (game_time_to_update_list, game_time_to_select_move_list) in enumerate(zip(time_to_update_list, time_to_select_move_list)):
    temp_mean_state_update_times = list()
    temp_mean_move_select_times = list()
    temp_median_state_update_times = list()
    temp_median_move_select_times = list()
    for update_step, select_step in zip(game_time_to_update_list, game_time_to_select_move_list):
        temp_mean_state_update_times.append(update_step.getMeanTime())
        temp_mean_move_select_times.append(select_step.getMeanTime())
        temp_median_state_update_times.append(update_step.getMedianTime())
        temp_median_move_select_times.append(select_step.getMedianTime())
    mean_state_update_times.append(temp_mean_state_update_times)
    mean_move_select_times.append(temp_mean_move_select_times)
    median_state_update_times.append(temp_median_state_update_times)
    median_move_select_times.append(temp_median_move_select_times)

# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.5, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,1.25,1,1], label='state_update_mean')
ax1.set_title('Mean Time Taken to Update State Against Step Number')
ax1.set_xlabel('Steps')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
for idx, game_mean_state_update_times in enumerate(mean_state_update_times):
    ax1.plot(game_mean_state_update_times, label=str(numNames[idx]))
ax1.legend()

# Draw mean graph for Move Select
ax2 = fig.add_axes([1.15,1.25,1,1], label='move_select_mean')
ax2.set_title('Mean Time Taken to Select Move Against Step Number')
ax2.set_xlabel('Steps')
ax2.set_ylabel('Time (ms)')
ax2.set_yscale('linear')
for idx, game_mean_move_select_times in enumerate(mean_move_select_times):
    ax2.plot(game_mean_move_select_times, label=str(numNames[idx]))
ax2.legend()

# Draw median graph for State Update
ax3 = fig.add_axes([0,0,1,1], label='state_update_median')
ax3.set_title('Median Time Taken to Update State Against Step Number')
ax3.set_xlabel('Steps')
ax3.set_ylabel('Time (ms)')
ax3.set_yscale('log')
for idx, game_median_state_update_times in enumerate(median_state_update_times):
    ax3.plot(game_median_state_update_times, label=str(numNames[idx]))
ax3.legend()

# Draw median graph for Move Select
ax4 = fig.add_axes([1.15,0,1,1], label='move_select_median')
ax4.set_title('Median Time Taken to Select Move Against Step Number')
ax4.set_xlabel('Steps')
ax4.set_ylabel('Time (ms)')
ax4.set_yscale('linear')
for idx, game_median_move_select_times in enumerate(median_move_select_times):
    ax4.plot(game_median_move_select_times, label=str(numNames[idx]))
ax4.legend()

plt.show()

# %%
sum_game_median_state_update_times = list()
for idx, game_median_state_update_times in enumerate(median_state_update_times):
    sum_game_median_state_update_times.append(sum(game_median_state_update_times)/len(game_median_state_update_times))
    
# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.15, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Median Time Taken to Update State')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
ax1.set_ylim([1,1000000])
ax1.bar(numNames, sum_game_median_state_update_times)

plt.show()
    
# sum_game_mean_state_update_times

# %%
sum_game_median_move_select_times = list()
for idx, game_median_move_select_times in enumerate(median_move_select_times):
    sum_game_median_move_select_times.append(sum(game_median_move_select_times)/len(game_median_move_select_times))
    
# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.15, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Median Time Taken to Select Move')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
ax1.set_ylim([1,100000])
ax1.bar(numNames, sum_game_median_move_select_times)

plt.show()
    
# sum_game_mean_state_update_times

# %% [markdown]
# ## Hypergame Utilization
#
# I will now consider how useful increasing the cap of hypergames was

# %%
max_hypergames = [2, 4, 8, 16, 32]

hypergame_utilization_sum = list()
hypergame_utilization_max = list()
hypergame_utilization_count = list()
hypergame_utilization = list()

fig = plt.figure()

for idx, move_list in enumerate(move_list_games):
    hypergame_utilization_sum.append([0] * max_num_steps[idx])
    hypergame_utilization_max.append([0] * max_num_steps[idx])
    hypergame_utilization_count.append([0] * max_num_steps[idx])
    hypergame_utilization.append([])

    # Count number of hypergames used on average at each step out of the maximum number
    for game in move_list:
        for index, row in game.iterrows():
            if(row['player_name'] == 'ophyper'):
                hypergame_utilization_sum[idx][row['step']] += row['count_hypergames']
                hypergame_utilization_count[idx][row['step']] += 1
                if(row['count_hypergames'] / max_hypergames[idx] > hypergame_utilization_max[idx][row['step']]):
                    hypergame_utilization_max[idx][row['step']] = row['count_hypergames'] / max_hypergames[idx]
    hypergame_utilization[idx] = [(utilSum / count) / max_hypergames[idx] for utilSum, count in zip(hypergame_utilization_sum[idx], hypergame_utilization_count[idx])]

    # display
    
    ax1 = fig.add_axes([0,-idx - idx*0.25,1,1])
    ax1.set_title('Average proportion of hypergame usage at each step for ' + str(numNames[idx]))
    ax1.set_xlabel('Step')
    ax1.set_ylabel('Hypergame usage out of max of ' + str(max_hypergames[idx]))
    ax1.set_yscale('linear')
    ax1.set_yticks(np.linspace(0,1,11))
    ax1.set_ylim([0,1])
    ax1.bar(range(0, len(hypergame_utilization[idx])), hypergame_utilization[idx])

    ax2 = fig.add_axes([1.25,-idx  - idx*0.25,1,1])
    ax2.set_title('Maximum hypergame usage at each step for ' + str(numNames[idx]))
    ax2.set_xlabel('Step')
    ax2.set_ylabel('Hypergame usage out of max of ' + str(max_hypergames[idx]))
    ax2.set_yscale('linear')
    ax2.set_yticks(np.linspace(0,1,11))
    ax2.set_ylim([0,1])
    ax2.bar(range(0, len(hypergame_utilization_max[idx])), hypergame_utilization_max[idx])

plt.show()

# %% [markdown]
# ### Steps taken to win

# %%
# Calculate the average number of steps taken to win for each hypergame
steps_to_win_list = list()
for idx, (move_list, game) in enumerate(zip(move_list_games, data)):
    game_steps_to_win_list = list()
    winning_games = game[((game['player_1_score'] == 100) & (game['player_2_score'] == 0)) | (len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)]))] 
    winning_games_list = winning_games['match_id'].tolist()
    for moves in move_list:
        if(moves['match_id'][0] in winning_games_list):
            move_length = len(moves['match_id'])
            game_steps_to_win_list.append(moves['step'][move_length - 1] + 1)
    steps_to_win_list.append(game_steps_to_win_list)

# Print steps to win
mean_steps_to_win = list()
median_steps_to_win = list()
for idx, game_steps_to_win in enumerate(steps_to_win_list):
    mean = statistics.mean(game_steps_to_win)
    median = statistics.median(game_steps_to_win)
    print(f'{numNames[idx]}')
    print(f'\tMean steps to win: {mean}')
    print(f'\tMedian steps to win: {median}')
    mean_steps_to_win.append(mean)
    median_steps_to_win.append(median)

# Graph steps to win
fig = plt.figure()
ax1 = fig.add_axes([0,0,1.75,1.5])
ax1.set_title('Mean Number of Steps Taken to Win')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Steps')
ax1.set_yscale('linear')
ax1.set_yticks(range(0,36,1))
ax1.set_ylim([0,36])
ax1.bar(numNames, mean_steps_to_win)

ax2 = fig.add_axes([0,-1.75,1.75,1.5])
ax2.set_title('Median Number of Steps Taken to Win')
ax2.set_xlabel('Agent')
ax2.set_ylabel('Steps')
ax2.set_yscale('linear')
ax2.set_yticks(range(0,36,1))
ax2.set_ylim([0,36])
ax2.bar(numNames, median_steps_to_win)

plt.show()
# Out:
# 2x2
# 	Mean steps to win: 25
# 	Median steps to win: 24.0
# 4x4
# 	Mean steps to win: 26
# 	Median steps to win: 26.0
# 8x8
# 	Mean steps to win: 28
# 	Median steps to win: 27.0
# 16x16
# 	Mean steps to win: 26
# 	Median steps to win: 26.0
# 32x32
# 	Mean steps to win: 26
# 	Median steps to win: 25.0
