# %% [markdown]
# # <center>OP Hyper</center>
#
# This file is an interactive notebook to analyze the data obtained from tests.<br>
# The purpose of this notebook is to define a baseline for a model which can be improved upon.
# The game blind_breakthrough will be used since this seems to be the game the original hyperplay model performed the best at.
#
# **Note: It could be a good idea to look into using a stronger cheat agent for a better comparison**
#
# ## Reading in the Data
#
# First the match data must be read in.
# I will be reading in data obtained for a series of games where a hyperplayer with increasing resources competed against a CHEAT player who had access to the true state and was allowed 16 simulations per move.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import statistics
np.random.seed(42)

# Read in the csv files
numNames = ['2x8', '4x8', '8x8', '16x8', '32x8', '64x8']
data = list()

for idx, name in enumerate(numNames):
    file_name = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ophyper_numhypergames/' + name + '/testOutput.csv'
    data.append(pd.DataFrame)
    data[idx] = pd.read_csv(file_name, header=0)

# Read in the csv files
data_ahyper = list()

for idx, name in enumerate(numNames):
    file_name = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ahyperlt_numhypergames/' + name + '/testOutput.csv'
    data_ahyper.append(pd.DataFrame)
    data_ahyper[idx] = pd.read_csv(file_name, header=0)
    
# Print the first 5 rows of the data
for game in data:
    display(game.head())
# Out:
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1600140080027          10       6000  XPLAYER          5
# 1            2  1600140183451          10       6000  XPLAYER          5
# 2            2  1600140398706          10       6000  XPLAYER          9
# 3            2  1600140578180          10       6000  XPLAYER          9
# 4            2  1600140721522          10       6000  XPLAYER          7
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 2  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPER              50  oplayer    CHEAT              50
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1600140304635          10       6000  XPLAYER          8
# 1            2  1600140521813          10       6000  XPLAYER          5
# 2            2  1600140715425          10       6000  XPLAYER          6
# 3            2  1600140841680          10       6000  XPLAYER          4
# 4            2  1600141088187          10       6000  XPLAYER          8
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 1  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 2  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 4  xplayer  OPHYPER               0  oplayer    CHEAT             100
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_1  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_2  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_3  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_4  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1600140266522          10       6000  XPLAYER          5
# 1            2  1600140942659          10       6000  XPLAYER          9
# 2            2  1600141270402          10       6000  XPLAYER          6
# 3            2  1600142017863          10       6000  XPLAYER         10
# 4            2  1600142316397          10       6000  XPLAYER          5
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER              50  oplayer    CHEAT              50
# 1  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 2  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 3  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPER             100  oplayer    CHEAT               0
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1600140705324          10       6000  XPLAYER          8
# 1            2  1600141300341          10       6000  XPLAYER          6
# 2            2  1600141687630          10       6000  XPLAYER          4
# 3            2  1600142575129          10       6000  XPLAYER         11
# 4            2  1600143248132          10       6000  XPLAYER          5
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER              50  oplayer    CHEAT              50
# 1  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 2  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 4  xplayer  OPHYPER              50  oplayer    CHEAT              50
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1600140537226          10       6000  XPLAYER          4
# 1            2  1600141481947          10       6000  XPLAYER          6
# 2            2  1600144370413          10       6000  XPLAYER         19
# 3            2  1600144936035          10       6000  XPLAYER          4
# 4            2  1600146217731          10       6000  XPLAYER          7
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 1  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 2  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 3  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 4  xplayer  OPHYPER               0  oplayer    CHEAT             100
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
#
#    gdl_version      timestamp  startclock  playclock sight_of  num_steps  \
# 0            2  1600141872009          10       6000  XPLAYER          5
# 1            2  1600144000561          10       6000  XPLAYER          6
# 2            2  1600146447287          10       6000  XPLAYER          7
# 3            2  1600147436758          10       6000  XPLAYER          4
# 4            2  1600148506123          10       6000  XPLAYER          4
#
#     role_1 player_1  player_1_score   role_2 player_2  player_2_score
# 0  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 1  xplayer  OPHYPER               0  oplayer    CHEAT             100
# 2  xplayer  OPHYPER              50  oplayer    CHEAT              50
# 3  xplayer  OPHYPER             100  oplayer    CHEAT               0
# 4  xplayer  OPHYPER             100  oplayer    CHEAT               0

# %% [markdown]
# Next, the move data should be read in for each match
#
# *Note: time_to_update and time_to_select_move are in milliseconds*

# %%
move_list_games = list()
for idx, name in enumerate(numNames):
    file_name_prefix = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ophyper_numhypergames/' + name + '/moveset/'
    temp_move_list = list()
    for match_name in data[idx]['match_id']:
        file_name = file_name_prefix + match_name + '.csv'
        temp_move_list.append(pd.read_csv(file_name, names=['match_id','game_name','step','role_name','player_name','count_hypergames','num_probes','time_to_update','time_to_select_move','move_chosen','last_move_illegal','numTimesMovesSimulated','numTimesHypergameForward']))
    move_list_games.append(temp_move_list)

move_list_games_ahyper = list()
for idx, name in enumerate(numNames):
    file_name_prefix = 'C:/Users/Michael/VirtualBox VMs/Shared/output/kriegTTT_5x5/ahyperlt_numhypergames/' + name + '/moveset/'
    temp_move_list = list()
    for match_name in data_ahyper[idx]['match_id']:
        file_name = file_name_prefix + match_name + '.csv'
        temp_move_list.append(pd.read_csv(file_name, names=['match_id','game_name','step','role_name','player_name','count_hypergames','num_probes','time_to_update','time_to_select_move','move_chosen','last_move_illegal','numTimesMovesSimulated','numTimesHypergameForward']))
    move_list_games_ahyper.append(temp_move_list)
    
# Verify by printing the head of the first game
for move_list in move_list_games:
    display(move_list[0])
# Out:
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 5  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 6  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 7  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 8  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 9  kriegTTT_5x5_CHEAT_2x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
#
#    step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0     0   XPLAYER     ophyper                 1           8              13
# 1     0   OPLAYER       cheat                 1          16              22
# 2     1   OPLAYER       cheat                 1          16              92
# 3     1   XPLAYER     ophyper                 2           8            6818
# 4     2   OPLAYER       cheat                 1          16              25
# 5     2   XPLAYER     ophyper                 2           8           11056
# 6     3   OPLAYER       cheat                 1          16              61
# 7     3   XPLAYER     ophyper                 2           8           10184
# 8     4   OPLAYER       cheat                 1          16              52
# 9     4   XPLAYER     ophyper                 2           8            9298
#
#    time_to_select_move  move_chosen  last_move_illegal  \
# 0                13884  (MARK 4 4 )              False
# 1                18892  (MARK 5 3 )              False
# 2                20735  (MARK 5 2 )              False
# 3                17607  (MARK 2 5 )              False
# 4                17052  (MARK 2 3 )              False
# 5                11951  (MARK 2 2 )              False
# 6                15586  (MARK 5 5 )              False
# 7                10983  (MARK 2 3 )              False
# 8                12266  (MARK 5 4 )              False
# 9                 9564  (MARK 5 5 )              False
#
#    numTimesMovesSimulated  numTimesHypergameForward
# 0                     200                         0
# 1                     375                         0
# 2                     360                        20
# 3                     484                         2
# 4                     345                         5
# 5                     560                         2
# 6                     330                        21
# 7                     536                         2
# 8                     315                        22
# 9                     512                        21
#                                              match_id           game_name  \
# 0   kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 1   kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 2   kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 3   kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 4   kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 5   kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 6   kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 7   kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 8   kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 9   kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 10  kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 11  kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 12  kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 13  kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 14  kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 15  kriegTTT_5x5_CHEAT_4x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
#
#     step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0      0   XPLAYER     ophyper                 1           8              16
# 1      0   OPLAYER       cheat                 1          16              15
# 2      1   OPLAYER       cheat                 1          16               8
# 3      1   XPLAYER     ophyper                 4           8            7605
# 4      2   OPLAYER       cheat                 1          16              16
# 5      2   XPLAYER     ophyper                 4           8           20498
# 6      3   OPLAYER       cheat                 1          16              66
# 7      3   XPLAYER     ophyper                 4           8           74092
# 8      4   OPLAYER       cheat                 1          16              16
# 9      4   XPLAYER     ophyper                 4           8           18443
# 10     5   OPLAYER       cheat                 1          16              26
# 11     5   XPLAYER     ophyper                 4           8           15234
# 12     6   OPLAYER       cheat                 1          16              11
# 13     6   XPLAYER     ophyper                 4           8           41569
# 14     7   OPLAYER       cheat                 1          16              31
# 15     7   XPLAYER     ophyper                 4           8           12795
#
#     time_to_select_move  move_chosen  last_move_illegal  \
# 0                 14483  (MARK 5 4 )              False
# 1                 19778  (MARK 4 3 )              False
# 2                 22334  (MARK 4 4 )              False
# 3                 28618  (MARK 4 1 )              False
# 4                 18151  (MARK 5 2 )              False
# 5                 17204  (MARK 2 4 )              False
# 6                 17529  (MARK 1 4 )              False
# 7                 16400  (MARK 4 5 )              False
# 8                 17359  (MARK 3 1 )              False
# 9                 12844  (MARK 2 2 )              False
# 10                15124  (MARK 3 3 )              False
# 11                10135  (MARK 1 3 )              False
# 12                12430  (MARK 2 3 )              False
# 13                13260  (MARK 3 3 )              False
# 14                10244  (MARK 5 3 )              False
# 15                13741  (MARK 2 1 )              False
#
#     numTimesMovesSimulated  numTimesHypergameForward
# 0                      200                         0
# 1                      375                         0
# 2                      360                         1
# 3                      868                         4
# 4                      345                         4
# 5                     1120                         5
# 6                      330                        21
# 7                     3284                       582
# 8                      315                         5
# 9                     1024                         4
# 10                     300                        12
# 11                     980                         4
# 12                     285                         4
# 13                    2892                       450
# 14                     270                        10
# 15                     888                        21
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 5  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 6  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 7  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 8  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
# 9  kriegTTT_5x5_CHEAT_8x8ophyper_16cheat_4OPProbes_0  kriegTTT_5x5_CHEAT
#
#    step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0     0   XPLAYER     ophyper                 1           8              13
# 1     0   OPLAYER       cheat                 1          16              16
# 2     1   OPLAYER       cheat                 1          16              95
# 3     1   XPLAYER     ophyper                 8           8            7180
# 4     2   OPLAYER       cheat                 1          16              20
# 5     2   XPLAYER     ophyper                 8           8           34419
# 6     3   OPLAYER       cheat                 1          16              21
# 7     3   XPLAYER     ophyper                 8           8           31348
# 8     4   OPLAYER       cheat                 1          16              67
# 9     4   XPLAYER     ophyper                 8           8           24810
#
#    time_to_select_move  move_chosen  last_move_illegal  \
# 0                14671  (MARK 5 4 )              False
# 1                20851  (MARK 2 5 )              False
# 2                22374  (MARK 3 2 )              False
# 3                56146  (MARK 3 2 )              False
# 4                20975  (MARK 4 5 )              False
# 5                46352  (MARK 4 4 )              False
# 6                17336  (MARK 3 5 )              False
# 7                40649  (MARK 2 4 )              False
# 8                 9325  (MARK 5 5 )              False
# 9                32247  (MARK 3 4 )              False
#
#    numTimesMovesSimulated  numTimesHypergameForward
# 0                     200                         0
# 1                     375                         0
# 2                     360                        18
# 3                    1636                         8
# 4                     345                         8
# 5                    2240                        57
# 6                     345                         9
# 7                    2208                         8
# 8                     330                        23
# 9                    2140                        10
#                                              match_id           game_name  \
# 0   kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 1   kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 2   kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 3   kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 4   kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 5   kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 6   kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 7   kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 8   kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 9   kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 10  kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 11  kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 12  kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 13  kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 14  kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 15  kriegTTT_5x5_CHEAT_16x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
#
#     step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0      0   XPLAYER     ophyper                 1           8              15
# 1      0   OPLAYER       cheat                 1          16              17
# 2      1   OPLAYER       cheat                 1          16              77
# 3      1   XPLAYER     ophyper                16           8            6744
# 4      2   OPLAYER       cheat                 1          16               9
# 5      2   XPLAYER     ophyper                16           8           53373
# 6      3   OPLAYER       cheat                 1          16              41
# 7      3   XPLAYER     ophyper                16           8           46246
# 8      4   OPLAYER       cheat                 1          16              39
# 9      4   XPLAYER     ophyper                16           8           85355
# 10     5   OPLAYER       cheat                 1          16              21
# 11     5   XPLAYER     ophyper                16           8           30955
# 12     6   OPLAYER       cheat                 1          16              19
# 13     6   XPLAYER     ophyper                16           8           37364
# 14     7   OPLAYER       cheat                 1          16              10
# 15     7   XPLAYER     ophyper                16           8           26054
#
#     time_to_select_move  move_chosen  last_move_illegal  \
# 0                 14702  (MARK 1 2 )              False
# 1                 20132  (MARK 3 3 )              False
# 2                 22041  (MARK 5 5 )              False
# 3                 90668  (MARK 3 4 )              False
# 4                 21024  (MARK 4 3 )              False
# 5                 72459  (MARK 5 4 )              False
# 6                 16891  (MARK 5 1 )              False
# 7                 64355  (MARK 4 4 )              False
# 8                 12528  (MARK 2 4 )              False
# 9                 47542  (MARK 2 4 )              False
# 10                12872  (MARK 2 1 )              False
# 11                46139  (MARK 4 3 )              False
# 12                11404  (MARK 3 1 )              False
# 13                42860  (MARK 2 5 )              False
# 14                 8047  (MARK 4 1 )              False
# 15                39182  (MARK 2 4 )              False
#
#     numTimesMovesSimulated  numTimesHypergameForward
# 0                      200                         0
# 1                      375                         0
# 2                      360                        13
# 3                     3172                        16
# 4                      345                         1
# 5                     4480                        42
# 6                      330                        15
# 7                     4288                        17
# 8                      315                        14
# 9                     6228                       548
# 10                     300                         5
# 11                    3916                        72
# 12                     300                         6
# 13                    4072                       171
# 14                     285                         3
# 15                    3796                        19
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 5  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 6  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 7  kriegTTT_5x5_CHEAT_32x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
#
#    step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0     0   XPLAYER     ophyper                 1           8               9
# 1     0   OPLAYER       cheat                 1          16              15
# 2     1   OPLAYER       cheat                 1          16              16
# 3     1   XPLAYER     ophyper                23           8            6968
# 4     2   OPLAYER       cheat                 1          16              80
# 5     2   XPLAYER     ophyper                32           8           67273
# 6     3   OPLAYER       cheat                 1          16              26
# 7     3   XPLAYER     ophyper                32           8          124130
#
#    time_to_select_move  move_chosen  last_move_illegal  \
# 0                15303  (MARK 3 2 )              False
# 1                20085  (MARK 2 4 )              False
# 2                21452  (MARK 5 2 )              False
# 3               122912  (MARK 3 4 )              False
# 4                18481  (MARK 1 5 )              False
# 5               129900  (MARK 3 3 )              False
# 6                10814  (MARK 3 5 )              False
# 7                75786  (MARK 3 1 )              False
#
#    numTimesMovesSimulated  numTimesHypergameForward
# 0                     200                         0
# 1                     375                         0
# 2                     360                         1
# 3                    4516                        25
# 4                     345                        18
# 5                    8096                        70
# 6                     330                        11
# 7                   10784                       639
#                                             match_id           game_name  \
# 0  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 1  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 2  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 3  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 4  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 5  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 6  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 7  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 8  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
# 9  kriegTTT_5x5_CHEAT_64x8ophyper_16cheat_4OPProb...  kriegTTT_5x5_CHEAT
#
#    step role_name player_name  count_hypergames  num_probes  time_to_update  \
# 0     0   XPLAYER     ophyper                 1           8               9
# 1     0   OPLAYER       cheat                 1          16              19
# 2     1   OPLAYER       cheat                 1          16             125
# 3     1   XPLAYER     ophyper                22           8            7329
# 4     2   OPLAYER       cheat                 1          16              37
# 5     2   XPLAYER     ophyper                64           8           77857
# 6     3   OPLAYER       cheat                 1          16              44
# 7     3   XPLAYER     ophyper                64           8          187173
# 8     4   OPLAYER       cheat                 1          16              57
# 9     4   XPLAYER     ophyper                54           8          666703
#
#    time_to_select_move  move_chosen  last_move_illegal  \
# 0                16183  (MARK 2 5 )              False
# 1                22392  (MARK 4 3 )              False
# 2                22505  (MARK 4 1 )              False
# 3               143167  (MARK 1 4 )              False
# 4                19911  (MARK 4 5 )              False
# 5               351057  (MARK 1 2 )              False
# 6                16832  (MARK 2 2 )              False
# 7               285462  (MARK 1 3 )              False
# 8                 9778  (MARK 3 3 )              False
# 9               156578  (MARK 1 1 )              False
#
#    numTimesMovesSimulated  numTimesHypergameForward
# 0                     200                         0
# 1                     375                         0
# 2                     360                        22
# 3                    4324                        25
# 4                     345                        10
# 5                   13888                       134
# 6                     330                        17
# 7                   17336                       119
# 8                     315                        20
# 9                   33464                      5419

# %% [markdown]
# ## Analysis of Data
#
# ### Overall Agent Results
#
# The average score of the agent will be calculated across all games

# %%
count_games_completed = list()
total_score_ophyper = list()
for idx, game in enumerate(data):
    total_score = data[idx]['player_1_score'][data[idx]['player_1_score'] >= 50].count() * 100
    total_count = len(data[idx]['player_1_score'])
    count_games_completed.append(total_count)
    total_score_ophyper.append(total_score)
    print(f"The win/draw rate for the agent \"" + str(data[idx]['player_1'][0]) + "\" playing the game \"" + str(data[idx]['game_name'][0]) + "\" with " + str(numNames[idx]) + f" probes is {(total_score/total_count):.2f}% for " + str(total_count) + " games")

# calc results for ahyper
win_count_ahyper = list()
total_score_ahyper = list()
for idx, game in enumerate(data_ahyper):
    total_score = data_ahyper[idx]['player_1_score'][data_ahyper[idx]['player_1_score'] >= 50].count() * 100
    total_score_ahyper.append(total_score)
    game_count = [len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 0)]), len(game[(game['player_1_score'] == 0) & (game['player_2_score'] == 100)]), len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)])]
    win_count_ahyper.append(game_count[0])
    
# Display a pie chart
fig = plt.figure()
data_len = len(data)
win_count = list()
for idx, game in enumerate(data):
    ax = fig.add_axes([(data_len - idx)%2,math.ceil((data_len - idx)/2),1,1])
    ax.axis('equal')
    ax.set_title('Win rate for ' + str(numNames[idx]))
    result = ['Won', 'Lost', 'Drew']
    game_count = [len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 0)]), len(game[(game['player_1_score'] == 0) & (game['player_2_score'] == 100)]), len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)])]
    win_count.append(game_count[0])
    ax.pie(game_count, labels = result,autopct='%1.1f%%')
plt.show()
# Out:
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 2x8 probes is 35.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 4x8 probes is 35.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 8x8 probes is 44.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 16x8 probes is 49.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 32x8 probes is 63.00% for 100 games
# The win/draw rate for the agent "OPHYPER" playing the game "kriegTTT_5x5_CHEAT" with 64x8 probes is 57.00% for 100 games

# %% [markdown]
# It is now worth looking into how performance degrades with fewer probes.
#
# First I will consider the number of games that can be completed without error compared to the number of probes.

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2], label='state_update')
ax1.set_title('Number of Games Completed')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Games Completed')
ax1.set_yscale('linear')
ax1.set_ylim([0,101])
ax1.bar(numNames, count_games_completed, color=u'#ff7f0e')
plt.show()

# %% [markdown]
# I will now consider whether the number of games won

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Proportion of Games Won that were Completed')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Games Won')
ax1.set_yscale('linear')
ax1.set_yticks(np.linspace(0, 100, 21))
ax1.set_ylim([0,100])
nobias_line, = ax1.plot(numNames, np.divide(total_score_ophyper,count_games_completed), marker='o', color=u'#ff7f0e')
plt.show()

# %% [markdown]
# Compared to ahyperlt

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Overall Score Against Number of Resources')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Overall Score')
ax1.set_yscale('linear')
ax1.set_yticks(np.linspace(0, 100, 21))
ax1.set_ylim([0,100])
ahyper_line, = ax1.plot(numNames, np.divide(total_score_ahyper,count_games_completed), marker='o')
nobias_line, = ax1.plot(numNames, np.divide(total_score_ophyper,count_games_completed), marker='o')
ax1.legend((nobias_line, ahyper_line), ('Opponent Modelling', 'Original Hyperplay'))
plt.show()

# %% [markdown]
# ### Move Results
#
# Calculating the average move time per game.
# This is expected to grow with the depth of the game and is expected to be different for the state update and the move selection.

# %%
class Tracker:
    '''
    Tracker tracks the average time for each move of each game played
    '''
    def __init__(self):
        self.time_sum = 0
        self.num_moves = 0
        self.times = list()
    
    def __str__(self):
        return "time_sum: " + str(self.time_sum) + " ms\n\tnum_moves: " + str(self.num_moves) + "\n\tmean_time: " + str(statistics.mean(self.times)) + "\n\tmedian_time: " + str(statistics.median(self.times)) + " ms\n\ttimes (ms): " + str(self.times)
    
    def addMove(self, num):
        self.time_sum += num
        self.num_moves+=1
        self.times.append(num)
    
    def getMeanTime(self):
        return statistics.mean(self.times)
    
    def getMedianTime(self):
        return statistics.median(self.times)

# Add the results for each move of each game played to a list of trackers for the update and select move times for the chosen player
time_to_update_list = list()
time_to_select_move_list = list()
max_num_steps = [0] * len(numNames)
for idx, (move_list, game) in enumerate(zip(move_list_games, data)):
    temp_time_to_update_list = list()
    temp_time_to_select_move_list = list()
    player_name = game['role_1'][0].upper()
    for move_set in move_list:
        for index, move_row in move_set.iterrows():
            if move_row['role_name'] == player_name:
                if move_row['step'] > len(temp_time_to_update_list) - 1:
                    max_num_steps[idx] += 1
                    temp_time_to_update_list.append(Tracker())
                    temp_time_to_select_move_list.append(Tracker())
                temp_time_to_update_list[move_row['step']].addMove(move_row['time_to_update'])
                temp_time_to_select_move_list[move_row['step']].addMove(move_row['time_to_select_move'])
    time_to_update_list.append(temp_time_to_update_list)
    time_to_select_move_list.append(temp_time_to_select_move_list)

# Print the data
for game_num, (game_time_to_update_list, game_time_to_select_move_list) in enumerate(zip(time_to_update_list, time_to_select_move_list)):
    print(str(numNames[game_num]))
    for idx, (update_step, select_step) in enumerate(zip(game_time_to_update_list, game_time_to_select_move_list)):
        print('\tStep: ' + str(idx) + "\n")
        print('\tTime taken to update states:')
        print('\t' + str(update_step)  + "\n")
        print('\tTime taken to select move:')
        print('\t' + str(select_step)  + "\n\n\n")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-007226e4a269> in <module>
#      37                     temp_time_to_update_list.append(Tracker())
#      38                     temp_time_to_select_move_list.append(Tracker())
# ---> 39                 temp_time_to_update_list[move_row['step']].addMove(move_row['time_to_update'])
#      40                 temp_time_to_select_move_list[move_row['step']].addMove(move_row['time_to_select_move'])
#      41     time_to_update_list.append(temp_time_to_update_list)
#
# IndexError: list index out of range

# %% [markdown]
# Now I will graph the findings

# %%
# Add the data to an array
mean_state_update_times = list()
mean_move_select_times = list()
median_state_update_times = list()
median_move_select_times = list()
for game_num, (game_time_to_update_list, game_time_to_select_move_list) in enumerate(zip(time_to_update_list, time_to_select_move_list)):
    temp_mean_state_update_times = list()
    temp_mean_move_select_times = list()
    temp_median_state_update_times = list()
    temp_median_move_select_times = list()
    for update_step, select_step in zip(game_time_to_update_list, game_time_to_select_move_list):
        temp_mean_state_update_times.append(update_step.getMeanTime())
        temp_mean_move_select_times.append(select_step.getMeanTime())
        temp_median_state_update_times.append(update_step.getMedianTime())
        temp_median_move_select_times.append(select_step.getMedianTime())
    mean_state_update_times.append(temp_mean_state_update_times)
    mean_move_select_times.append(temp_mean_move_select_times)
    median_state_update_times.append(temp_median_state_update_times)
    median_move_select_times.append(temp_median_move_select_times)

# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.5, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,1.25,1,1], label='state_update_mean')
ax1.set_title('Mean Time Taken to Update State Against Step Number')
ax1.set_xlabel('Steps')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
for idx, game_mean_state_update_times in enumerate(mean_state_update_times):
    ax1.plot(game_mean_state_update_times, label=str(numNames[idx]))
ax1.legend()

# Draw mean graph for Move Select
ax2 = fig.add_axes([1.15,1.25,1,1], label='move_select_mean')
ax2.set_title('Mean Time Taken to Select Move Against Step Number')
ax2.set_xlabel('Steps')
ax2.set_ylabel('Time (ms)')
ax2.set_yscale('linear')
for idx, game_mean_move_select_times in enumerate(mean_move_select_times):
    ax2.plot(game_mean_move_select_times, label=str(numNames[idx]))
ax2.legend()

# Draw median graph for State Update
ax3 = fig.add_axes([0,0,1,1], label='state_update_median')
ax3.set_title('Median Time Taken to Update State Against Step Number')
ax3.set_xlabel('Steps')
ax3.set_ylabel('Time (ms)')
ax3.set_yscale('log')
for idx, game_median_state_update_times in enumerate(median_state_update_times):
    ax3.plot(game_median_state_update_times, label=str(numNames[idx]))
ax3.legend()

# Draw median graph for Move Select
ax4 = fig.add_axes([1.15,0,1,1], label='move_select_median')
ax4.set_title('Median Time Taken to Select Move Against Step Number')
ax4.set_xlabel('Steps')
ax4.set_ylabel('Time (ms)')
ax4.set_yscale('linear')
for idx, game_median_move_select_times in enumerate(median_move_select_times):
    ax4.plot(game_median_move_select_times, label=str(numNames[idx]))
ax4.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
sum_game_median_state_update_times = list()
for idx, game_median_state_update_times in enumerate(median_state_update_times):
    sum_game_median_state_update_times.append(sum(game_median_state_update_times)/len(game_median_state_update_times))
    
# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.15, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Median Time Taken to Update State')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
ax1.set_ylim([1,100000])
ax1.bar(numNames, sum_game_median_state_update_times)

plt.show()
    
# sum_game_mean_state_update_times
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-37881f15e981> in <module>
#      14 ax1.set_yscale('log')
#      15 ax1.set_ylim([1,100000])
# ---> 16 ax1.bar(numNames, sum_game_median_state_update_times)
#      17
#      18 plt.show()
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     257     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     258
# --> 259     shape = _broadcast_shape(*args)
#     260
#     261     if all(array.shape == shape for array in args):
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     191     # use the old-iterator because np.nditer does not handle size 0 arrays
#     192     # consistently
# --> 193     b = np.broadcast(*args[:32])
#     194     # unfortunately, it cannot handle 32 or more arguments directly
#     195     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
sum_game_median_move_select_times = list()
for idx, game_median_move_select_times in enumerate(median_move_select_times):
    sum_game_median_move_select_times.append(sum(game_median_move_select_times)/len(game_median_move_select_times))
    
# Put into graphs
fig = plt.figure()
fig.suptitle(str(data[0]['game_name'][0]), x=1, y=2.15, fontsize=18)

# Draw mean graph for State Update
ax1 = fig.add_axes([0,0,2,2])
ax1.set_title('Median Time Taken to Select Move')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Time (ms)')
ax1.set_yscale('log')
ax1.set_ylim([1,1000000])
ax1.bar(numNames, sum_game_median_move_select_times)

plt.show()
    
# sum_game_mean_state_update_times
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-9a0ecf108826> in <module>
#      14 ax1.set_yscale('log')
#      15 ax1.set_ylim([1,1000000])
# ---> 16 ax1.bar(numNames, sum_game_median_move_select_times)
#      17
#      18 plt.show()
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     257     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     258
# --> 259     shape = _broadcast_shape(*args)
#     260
#     261     if all(array.shape == shape for array in args):
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     191     # use the old-iterator because np.nditer does not handle size 0 arrays
#     192     # consistently
# --> 193     b = np.broadcast(*args[:32])
#     194     # unfortunately, it cannot handle 32 or more arguments directly
#     195     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %% [markdown]
# ## Hypergame Utilization
#
# I will now consider how useful increasing the cap of hypergames was

# %%
max_hypergames = [2, 4, 8, 16, 32, 64]

hypergame_utilization_sum = list()
hypergame_utilization_max = list()
hypergame_utilization_count = list()
hypergame_utilization = list()

fig = plt.figure()

for idx, move_list in enumerate(move_list_games):
    hypergame_utilization_sum.append([0] * max_num_steps[idx])
    hypergame_utilization_max.append([0] * max_num_steps[idx])
    hypergame_utilization_count.append([0] * max_num_steps[idx])
    hypergame_utilization.append([])

    # Count number of hypergames used on average at each step out of the maximum number
    for game in move_list:
        for index, row in game.iterrows():
            if(row['player_name'] == 'ophyper'):
                hypergame_utilization_sum[idx][row['step']] += row['count_hypergames']
                hypergame_utilization_count[idx][row['step']] += 1
                if(row['count_hypergames'] / max_hypergames[idx] > hypergame_utilization_max[idx][row['step']]):
                    hypergame_utilization_max[idx][row['step']] = row['count_hypergames'] / max_hypergames[idx]
    hypergame_utilization[idx] = [(utilSum / count) / max_hypergames[idx] for utilSum, count in zip(hypergame_utilization_sum[idx], hypergame_utilization_count[idx])]

    # display
    
    ax1 = fig.add_axes([0,-idx - idx*0.25,1,1])
    ax1.set_title('Average proportion of hypergame usage at each step for ' + str(numNames[idx]))
    ax1.set_xlabel('Step')
    ax1.set_ylabel('Hypergame usage out of max of ' + str(max_hypergames[idx]))
    ax1.set_yscale('linear')
    ax1.set_yticks(np.linspace(0,1,11))
    ax1.set_ylim([0,1])
    ax1.bar(range(0, len(hypergame_utilization[idx])), hypergame_utilization[idx])

    ax2 = fig.add_axes([1.25,-idx  - idx*0.25,1,1])
    ax2.set_title('Maximum hypergame usage at each step for ' + str(numNames[idx]))
    ax2.set_xlabel('Step')
    ax2.set_ylabel('Hypergame usage out of max of ' + str(max_hypergames[idx]))
    ax2.set_yscale('linear')
    ax2.set_yticks(np.linspace(0,1,11))
    ax2.set_ylim([0,1])
    ax2.bar(range(0, len(hypergame_utilization_max[idx])), hypergame_utilization_max[idx])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-e2a4fb244ace> in <module>
#      18         for index, row in game.iterrows():
#      19             if(row['player_name'] == 'ophyper'):
# ---> 20                 hypergame_utilization_sum[idx][row['step']] += row['count_hypergames']
#      21                 hypergame_utilization_count[idx][row['step']] += 1
#      22                 if(row['count_hypergames'] / max_hypergames[idx] > hypergame_utilization_max[idx][row['step']]):
#
# IndexError: list index out of range

# %% [markdown]
# ### Steps taken to win

# %%
# Calculate the average number of steps taken to win for each hypergame
steps_to_win_list = list()
for idx, (move_list, game) in enumerate(zip(move_list_games, data)):
    game_steps_to_win_list = list()
    winning_games = game[((game['player_1_score'] == 100) & (game['player_2_score'] == 0)) | (len(game[(game['player_1_score'] == 100) & (game['player_2_score'] == 100)| (game['player_1_score'] == 50) & (game['player_2_score'] == 50)]))] 
    winning_games_list = winning_games['match_id'].tolist()
    for moves in move_list:
        if(moves['match_id'][0] in winning_games_list):
            move_length = len(moves['match_id'])
            game_steps_to_win_list.append(moves['step'][move_length - 1] + 1)
    steps_to_win_list.append(game_steps_to_win_list)

# Print steps to win
mean_steps_to_win = list()
median_steps_to_win = list()
for idx, game_steps_to_win in enumerate(steps_to_win_list):
    mean = statistics.mean(game_steps_to_win)
    median = statistics.median(game_steps_to_win)
    print(f'{numNames[idx]}')
    print(f'\tMean steps to win: {mean}')
    print(f'\tMedian steps to win: {median}')
    mean_steps_to_win.append(mean)
    median_steps_to_win.append(median)

# Graph steps to win
fig = plt.figure()
ax1 = fig.add_axes([0,0,1.75,1.5])
ax1.set_title('Mean Number of Steps Taken to Win')
ax1.set_xlabel('Agent')
ax1.set_ylabel('Steps')
ax1.set_yscale('linear')
ax1.set_yticks(range(0,36,1))
ax1.set_ylim([0,36])
ax1.bar(numNames, mean_steps_to_win)

ax2 = fig.add_axes([0,-1.75,1.75,1.5])
ax2.set_title('Median Number of Steps Taken to Win')
ax2.set_xlabel('Agent')
ax2.set_ylabel('Steps')
ax2.set_yscale('linear')
ax2.set_yticks(range(0,36,1))
ax2.set_ylim([0,36])
ax2.bar(numNames, median_steps_to_win)

plt.show()
# Out:
# 2x8
# 	Mean steps to win: 6
# 	Median steps to win: 6.0
# 4x8
# 	Mean steps to win: 6
# 	Median steps to win: 6.0
# 8x8
# 	Mean steps to win: 6
# 	Median steps to win: 6.0
# 16x8
# 	Mean steps to win: 6
# 	Median steps to win: 5.5
# 32x8
# 	Mean steps to win: 6
# 	Median steps to win: 5.5
# 64x8
# 	Mean steps to win: 6
# 	Median steps to win: 6.0
